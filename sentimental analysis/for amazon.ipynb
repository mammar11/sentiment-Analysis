# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
search_query="samsung+m34+5g"

# %%
base_url="https://www.amazon.in/s?k="

# %%
url= base_url+search_query
url
# Out:
# 'https://www.amazon.in/s?k=samsung+m34+5g'

# %%
header={
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36',
    'referer':'https://www.amazon.in/s?k=samsung+m34+5g&crid=22DKOX8E8HAPI&sprefix=sams%2Caps%2C231&ref=nb_sb_ss_inft-rank-pairwise-in-t1_3_4'
}

# %%
search_response=requests.get(url,headers=header)

# %%
search_response.status_code
# Out:
# 200

# %%
search_response.text
# Out:
# '<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<!-- sp:end-feature:head-start -->\n<!-- sp:feature:csm:head-open-part1 -->\n\n<script type=\'text/javascript\'>var ue_t0=ue_t0||+new Date();</script>\n<!-- sp:end-feature:csm:head-open-part1 -->\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com" crossorigin>\n<link rel="preconnect" href="https://images-eu.ssl-images-amazon.com" crossorigin>\n<link rel="dns-prefetch" href="https://m.media-amazon.com" crossorigin>\n<link rel="preconnect" href="https://m.media-amazon.com" crossorigin>\n<link rel="dns-prefetch" href="https://completion.amazon.com" crossorigin>\n<link rel="preconnect" href="https://completion.amazon.com" crossorigin>\n<!-- sp:end-feature:cs-optimization -->\n<!--
# ...

# %%
search_response.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='session-id', value='262-8485102-9472525', port=None, port_specified=False, domain='.amazon.in', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=1724997429, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='session-id-time', value='2082787201l', port=None, port_specified=False, domain='.amazon.in', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=1724997429, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='i18n-prefs', value='INR', port=None, port_specified=False, domain='.amazon.in', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=1724997429, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False)]>

# %%
cookie={} # insert request cookies within{}
def getAmazonSearch(search_query):
    url="https://www.amazon.in/s?k="+search_query
    print(url)
    page=requests.get(url,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %%
getAmazonSearch(search_query)
# Out:
# https://www.amazon.in/s?k=samsung+m34+5g
# <Response [200]>

# %%
def Searchasin(asin):
    url="https://www.amazon.in/dp/"+asin
    print(url)
    page=requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %%
asin="B0C7BZX934"
Searchasin(asin)
# Out:
# https://www.amazon.in/dp/B0C7BZX934
# <Response [200]>

# %%
def Searchreviews(review_link):
    url="https://www.amazon.in"+review_link
    print(url)
    page=requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %%
product_names=[]
response=getAmazonSearch('samsung+m34+5g')
soup=BeautifulSoup(response.content)
for i in soup.findAll("span",{'class':'a-size-medium a-color-base a-text-normal'}): # the tag which is common for all the names of products
    product_names.append(i.text) #adding the product names to the list
# Out:
# https://www.amazon.in/s?k=samsung+m34+5g

# %%
product_names
# Out:
# ['Samsung Galaxy M34 5G (Midnight Blue, 6GB, 128GB Storage) | 120Hz sAMOLED Display | 50MP Triple No Shake Cam | 6000 mAh Battery | 12GB RAM with RAM Plus | Android 13 | Without Charger',
#  'Samsung Galaxy S23 5G (Green, 8GB, 256GB Storage)',
#  'Samsung Galaxy M34 5G (Waterfall Blue, 6GB, 128GB Storage) | 120Hz sAMOLED Display | 50MP Triple No Shake Cam | 6000 mAh Battery | 12GB RAM with RAM Plus | Android 13 | Without Charger',
#  'Samsung Galaxy M34 5G (Waterfall Blue, 8GB, 128GB Storage) | 120Hz sAMOLED Display | 50MP Triple No Shake Cam | 6000 mAh Battery | 16GB RAM with RAM Plus | Android 13 | Without Charger',
#  'Samsung Galaxy M34 5G (Midnight Blue, 6GB, 128GB Storage) | 120Hz sAMOLED Display | 50MP Triple No Shake Cam | 6000 mAh Battery | 12GB RAM with RAM Plus | Android 13 | Without Charger',
# ...

# %%
len(product_names)
# Out:
# 22

# %%
data_asin=[]
response=getAmazonSearch('samsung+m34+5g')
soup=BeautifulSoup(response.content)
for i in soup.findAll("div",{'class':"sg-col-20-of-24 s-result-item s-asin sg-col-0-of-12 sg-col-16-of-20 AdHolder sg-col s-widget-spacing-small sg-col-12-of-16"}):
    data_asin.append(i['data-asin'])
# Out:
# https://www.amazon.in/s?k=samsung+m34+5g

# %%
response.status_code

# %%
data_asin
# Out:
# ['B0C7BZX934', 'B0BT9DVZLZ', 'B0BT9G7RYH', 'B0CDYXMSLP', 'B0CBRR54KF']

# %%
len(data_asin)
# Out:
# 5

# %%
link=[]
for i in range(len(data_asin)):
    response=Searchasin(data_asin[i])
    soup=BeautifulSoup(response.content)
    for i in soup.findAll("a",{'data-hook':"see-all-reviews-link-foot"}):
        link.append(i['href'])
# Out:
# https://www.amazon.in/dp/B0C7BZX934
# https://www.amazon.in/dp/B0BT9DVZLZ
# https://www.amazon.in/dp/B0BT9G7RYH
# https://www.amazon.in/dp/B0CDYXMSLP
# https://www.amazon.in/dp/B0CBRR54KF

# %%
len(link)
# Out:
# 5

# %%
link
# Out:
# ['/Samsung-Midnight-Storage-sAMOLED-Display/product-reviews/B0C7BZX934/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
#  '/Samsung-Galaxy-Green-256GB-Storage/product-reviews/B0BT9DVZLZ/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
#  '/Samsung-Galaxy-Ultra-Green-Storage/product-reviews/B0BT9G7RYH/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
#  '/Storage-Segment-Charging-6000mAh-Textured/product-reviews/B0CDYXMSLP/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
#  '/Lava-Blaze-5G-Green-Expandable/product-reviews/B0CBRR54KF/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews']

# %%
reviews=[]
for j in range(len(link)):
    for k in range(100):
        response=Searchreviews(link[j]+'&pageNumber='+str(k))
        soup=BeautifulSoup(response.content)
        for i in soup.findAll("span",{'data-hook':"review-body"}):
            reviews.append(i.text)
# Out:
# https://www.amazon.in/Samsung-Midnight-Storage-sAMOLED-Display/product-reviews/B0C7BZX934/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Samsung-Midnight-Storage-sAMOLED-Display/product-reviews/B0C7BZX934/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Samsung-Midnight-Storage-sAMOLED-Display/product-reviews/B0C7BZX934/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Samsung-Midnight-Storage-sAMOLED-Display/product-reviews/B0C7BZX934/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Samsung-Midnight-Storage-sAMOLED-Display/product-reviews/B0C7BZX934/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Samsung-Midnight-Storage-sAMOLED-Display/product-reviews/B0C7BZX934/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# ...

# %%
len(reviews)
# Out:
# 448

# %%
rev={'reviews':reviews}

# %%
review_data=pd.DataFrame.from_dict(rev)
pd.set_option('max_colwidth',800)

# %%
review_data.head(5)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            reviews
# ...

# %%
review_data.shape
# Out:
# (448, 1)

# %%
review_data.to_csv('Scraping reviews.csv') #converting the dataframe to a csv file so as to use it later for further analysis
