# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
import nltk

# %%
# pip install nltk

# %%
df=pd.read_csv('walmart_reviews.csv')

# %%
# df.head(5)
# Out:
#    Unnamed: 0                                            reviews
# 0           0  4 out of 5 stars reviewGreat features, able to...
# 1           1  1 out of 5 stars reviewBlack dot on screenJust...
# 2           2  5 out of 5 stars review8/8/2023TV is so simple...
# 3           3  5 out of 5 stars review6/1/2023Incredible Ease...
# 4           4  5 out of 5 stars review4/29/2023it connects so...

# %%
# df.reviews[0]
# Out:
# "4 out of 5 stars reviewGreat features, able to play Xbox without console[This review was collected as part of a promotion.] Love the Xbox gaming feature without the need for a console to be connected directly to the TV. Great picture and colors. One Con is that the TV sometimes is slow to respond to changes when using the remote and line of site is clear.OhMarcPaulWritten by aSamsung UScustomerSamsung Brand AmbassadorHi OhMarcPaul,\n\nI'm happy to hear you are enjoying your new CU8000 TV with Samsung Gaming Hub. If you are experiencing issues...See more"

# %%
df.rating=df.reviews[0]

# %%
df['Rating'] = df['reviews'].str.extract(r'(\d+(\.\d+)?) out of 5 stars')[0]

# %%
df['reviews'] = df['reviews'].str.slice(start=23)

# %%
# df.head()
# Out:
#    Unnamed: 0                                            reviews Rating
# 0           0  Great features, able to play Xbox without cons...      4
# 1           1  Black dot on screenJust purchase this tv and a...      1
# 2           2  8/8/2023TV is so simple to use.[This review wa...      5
# 3           3  6/1/2023Incredible Ease of navigation[This rev...      5
# 4           4  4/29/2023it connects so seamlessly with my sam...      5

# %%
r=df['Rating'].value_counts().sort_index().plot(kind='bar',title= 'count of reviews',figsize=(10,5))

# %%
example=df.reviews[282]
# print(example)
# Out:
# 10/26/2022great quality at a great price[This review was collected as part of a promotion.] I have an older 36" Samsung  (2006 Touch Of Red model)  I wanted to replace.    Not because it didn't work but because I wanted a new modern smart TV Samsung builds TV's to last,  16 years is a long time for a TV hold up and keep working
#     Anyway A few weeks ago I purchased  a 43 inch Tu7000 for the bedroom.    I was seeking a thin modern affordable TV with a great picture    This was the ultimate choice!   I also find this model has decent internal sound,  without a soundbar   but of course you can always add one which I'll do soon to watch my music videos.
# .KateTheGreat00Written by aSamsung UScustomer

# %%
df2 = df.copy()

# %%
# df2.head()
# Out:
#    Unnamed: 0                                            reviews Rating
# 0           0  Great features, able to play Xbox without cons...      4
# 1           1  Black dot on screenJust purchase this tv and a...      1
# 2           2  8/8/2023TV is so simple to use.[This review wa...      5
# 3           3  6/1/2023Incredible Ease of navigation[This rev...      5
# 4           4  4/29/2023it connects so seamlessly with my sam...      5

# %%
# Define a function to remove the first 8 characters from reviews that start with a number
def remove_first_8_characters(review):
    if review and review[0].isdigit():
        return review[8:]
    else:
        return review


df2['reviews'] = df2['reviews'].apply(remove_first_8_characters)

# Display the DataFrame
# print(df2)
# Out:
#      Unnamed: 0                                            reviews Rating
# 0             0  Great features, able to play Xbox without cons...      4
# 1             1  Black dot on screenJust purchase this tv and a...      1
# 2             2  TV is so simple to use.[This review was collec...      5
# 3             3  Incredible Ease of navigation[This review was ...      5
# 4             4  3it connects so seamlessly with my samsung ear...      5
# ..          ...                                                ...    ...
# 281         281  22It has been a great tv since day one[This re...      5
# 282         282  22great quality at a great price[This review w...      5
# 283         283  2Happy with the clear display[This review was ...      5
# 284         284  2Solid tv for avg person[This review was colle...      4
# 285         285  2Great, but blurry at night.[This review was c...      5
#
# [286 rows x 3 columns]

# %%
df2['reviews'] = df2['reviews'].str.replace(r'[This review was collected as part of a promotion.]', '')

# %%
df3=df2

# %%
# df3.head()
# Out:
#    Unnamed: 0                                            reviews Rating
# 0           0  Great features, able to play Xbox without cons...      4
# 1           1  Black dot on screenJust purchase this tv and a...      1
# 2           2  TV is so simple to use. This Samsung Crystal U...      5
# 3           3  Incredible Ease of navigation For someone bein...      5
# 4           4  3it connects so seamlessly with my samsung ear...      5

# %%
df3['reviews'] = df3['reviews'].str.replace(r'^\d+\s*', '', regex=True)

# %%
# df3.reviews[282]
# Out:
# 'great quality at a great price I have an older 36" Samsung  (2006 Touch Of Red model)  I wanted to replace.    Not because it didn\'t work but because I wanted a new modern smart TV Samsung builds TV\'s to last,  16 years is a long time for a TV hold up and keep working         \n    Anyway A few weeks ago I purchased  a 43 inch Tu7000 for the bedroom.    I was seeking a thin modern affordable TV with a great picture    This was the ultimate choice!   I also find this model has decent internal sound,  without a soundbar   but of course you can always add one which I\'ll do soon to watch my music videos.  \n.KateTheGreat00Written by aSamsung UScustomer'

# %%
example=df3.reviews[282]
# print(example)
# Out:
# great quality at a great price I have an older 36" Samsung  (2006 Touch Of Red model)  I wanted to replace.    Not because it didn't work but because I wanted a new modern smart TV Samsung builds TV's to last,  16 years is a long time for a TV hold up and keep working
#     Anyway A few weeks ago I purchased  a 43 inch Tu7000 for the bedroom.    I was seeking a thin modern affordable TV with a great picture    This was the ultimate choice!   I also find this model has decent internal sound,  without a soundbar   but of course you can always add one which I'll do soon to watch my music videos.
# .KateTheGreat00Written by aSamsung UScustomer

# %%
# print(df3)
# Out:
#      Unnamed: 0                                            reviews Rating
# 0             0  Great features, able to play Xbox without cons...      4
# 1             1  Black dot on screenJust purchase this tv and a...      1
# 2             2  TV is so simple to use. This Samsung Crystal U...      5
# 3             3  Incredible Ease of navigation For someone bein...      5
# 4             4  it connects so seamlessly with my samsung earb...      5
# ..          ...                                                ...    ...
# 281         281  It has been a great tv since day one My family...      5
# 282         282  great quality at a great price I have an older...      5
# 283         283  Happy with the clear display I purchased my 43...      5
# 284         284  Solid tv for avg person So I have the 7000 ser...      4
# 285         285  Great, but blurry at night. Like I said, it is...      5
#
# [286 rows x 3 columns]

# %%
tokens=nltk.word_tokenize(example)
# tokens
# Out:
# ['great',
#  'quality',
#  'at',
#  'a',
#  'great',
#  'price',
#  'I',
#  'have',
#  'an',
#  'older',
#  '36',
#  "''",
#  'Samsung',
#  '(',
#  '2006',
#  'Touch',
#  'Of',
#  'Red',
#  'model',
#  ')',
#  'I',
#  'wanted',
#  'to',
#  'replace',
#  '.',
#  'Not',
#  'because',
#  'it',
#  'did',
#  "n't",
#  'work',
#  'but',
#  'because',
#  'I',
#  'wanted',
#  'a',
#  'new',
#  'modern',
#  'smart',
#  'TV',
#  'Samsung',
#  'builds',
#  'TV',
#  "'s",
#  'to',
#  'last',
#  ',',
#  '16',
#  'years',
#  'is',
#  'a',
#  'long',
#  'time',
#  'for',
#  'a',
#  'TV',
#  'hold',
#  'up',
#  'and',
#  'keep',
#  'working',
#  'Anyway',
#  'A',
#  'few',
#  'weeks',
#  'ago',
#  'I',
#  'purchased',
#  'a',
#  '43',
#  'inch',
#  'Tu7000',
#  'for',
#  'the',
#  'bedroom',
#  '.',
#  'I',
#  'was',
#  'seeking',
#  'a',
#  'thin',
#  'modern',
#  'affordable',
#  'TV',
#  'with',
#  'a',
#  'great',
#  'picture',
#  'This',
#  'was',
#  'the',
#  'ultimate',
#  'choice',
#  '!',
#  'I',
#  'also',
#  'find',
#  'this',
#  'model',
#  'has',
#  'decent',
#  'internal',
#  'sound',
#  ',',
#  'without',
#  'a',
#  'soundbar',
#  'but',
#  'of',
#  'course',
#  'you',
#  'can',
#  'always',
#  'add',
#  'one',
#  'which',
#  'I',
#  "'ll",
#  'do',
#  'soon',
#  'to',
#  'watch',
#  'my',
#  'music',
#  'videos',
#  '.',
#  '.KateTheGreat00Written',
#  'by',
#  'aSamsung',
#  'UScustomer']

# %%
# nltk.download('punkt')

# %%
# nltk.download('averaged_perceptron_tagger')

# %%
tags=nltk.pos_tag(tokens)
# tags
# Out:
# [('great', 'JJ'),
#  ('quality', 'NN'),
#  ('at', 'IN'),
#  ('a', 'DT'),
#  ('great', 'JJ'),
#  ('price', 'NN'),
#  ('I', 'PRP'),
#  ('have', 'VBP'),
#  ('an', 'DT'),
#  ('older', 'JJR'),
#  ('36', 'CD'),
#  ("''", "''"),
#  ('Samsung', 'NNP'),
#  ('(', '('),
#  ('2006', 'CD'),
#  ('Touch', 'NNP'),
#  ('Of', 'IN'),
#  ('Red', 'NNP'),
#  ('model', 'NN'),
#  (')', ')'),
#  ('I', 'PRP'),
#  ('wanted', 'VBD'),
#  ('to', 'TO'),
#  ('replace', 'VB'),
#  ('.', '.'),
#  ('Not', 'RB'),
#  ('because', 'IN'),
#  ('it', 'PRP'),
#  ('did', 'VBD'),
#  ("n't", 'RB'),
#  ('work', 'VB'),
#  ('but', 'CC'),
#  ('because', 'IN'),
#  ('I', 'PRP'),
#  ('wanted', 'VBD'),
#  ('a', 'DT'),
#  ('new', 'JJ'),
#  ('modern', 'JJ'),
#  ('smart', 'JJ'),
#  ('TV', 'NN'),
#  ('Samsung', 'NNP'),
#  ('builds', 'VBZ'),
#  ('TV', 'NN'),
#  ("'s", 'POS'),
#  ('to', 'TO'),
#  ('last', 'JJ'),
#  (',', ','),
#  ('16', 'CD'),
#  ('years', 'NNS'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('long', 'JJ'),
#  ('time', 'NN'),
#  ('for', 'IN'),
#  ('a', 'DT'),
#  ('TV', 'NN'),
#  ('hold', 'NN'),
#  ('up', 'RP'),
#  ('and', 'CC'),
#  ('keep', 'VB'),
#  ('working', 'VBG'),
#  ('Anyway', 'RB'),
#  ('A', 'NNP'),
#  ('few', 'JJ'),
#  ('weeks', 'NNS'),
#  ('ago', 'RB'),
#  ('I', 'PRP'),
#  ('purchased', 'VBD'),
#  ('a', 'DT'),
#  ('43', 'CD'),
#  ('inch', 'NN'),
#  ('Tu7000', 'NNP'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('bedroom', 'NN'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('was', 'VBD'),
#  ('seeking', 'VBG'),
#  ('a', 'DT'),
#  ('thin', 'JJ'),
#  ('modern', 'JJ'),
#  ('affordable', 'JJ'),
#  ('TV', 'NN'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('great', 'JJ'),
#  ('picture', 'NN'),
#  ('This', 'DT'),
#  ('was', 'VBD'),
#  ('the', 'DT'),
#  ('ultimate', 'JJ'),
#  ('choice', 'NN'),
#  ('!', '.'),
#  ('I', 'PRP'),
#  ('also', 'RB'),
#  ('find', 'VBP'),
#  ('this', 'DT'),
#  ('model', 'NN'),
#  ('has', 'VBZ'),
#  ('decent', 'VBN'),
#  ('internal', 'JJ'),
#  ('sound', 'NN'),
#  (',', ','),
#  ('without', 'IN'),
#  ('a', 'DT'),
#  ('soundbar', 'NN'),
#  ('but', 'CC'),
#  ('of', 'IN'),
#  ('course', 'NN'),
#  ('you', 'PRP'),
#  ('can', 'MD'),
#  ('always', 'RB'),
#  ('add', 'VB'),
#  ('one', 'CD'),
#  ('which', 'WDT'),
#  ('I', 'PRP'),
#  ("'ll", 'MD'),
#  ('do', 'VB'),
#  ('soon', 'RB'),
#  ('to', 'TO'),
#  ('watch', 'VB'),
#  ('my', 'PRP$'),
#  ('music', 'NN'),
#  ('videos', 'NN'),
#  ('.', '.'),
#  ('.KateTheGreat00Written', 'VBN'),
#  ('by', 'IN'),
#  ('aSamsung', 'NN'),
#  ('UScustomer', 'NN')]

# %%
# nltk.download('maxent_ne_chunker')
# nltk.download('words')
# pip install svgling

# %%
# import svgling

# %%
# chnk=nltk.chunk.ne_chunk(tags)
# chnk
# Out:
# Tree('S', [('great', 'JJ'), ('quality', 'NN'), ('at', 'IN'), ('a', 'DT'), ('great', 'JJ'), ('price', 'NN'), ('I', 'PRP'), ('have', 'VBP'), ('an', 'DT'), ('older', 'JJR'), ('36', 'CD'), ("''", "''"), Tree('GPE', [('Samsung', 'NNP')]), ('(', '('), ('2006', 'CD'), ('Touch', 'NNP'), ('Of', 'IN'), Tree('GPE', [('Red', 'NNP')]), ('model', 'NN'), (')', ')'), ('I', 'PRP'), ('wanted', 'VBD'), ('to', 'TO'), ('replace', 'VB'), ('.', '.'), ('Not', 'RB'), ('because', 'IN'), ('it', 'PRP'), ('did', 'VBD'), ("n't", 'RB'), ('work', 'VB'), ('but', 'CC'), ('because', 'IN'), ('I', 'PRP'), ('wanted', 'VBD'), ('a', 'DT'), ('new', 'JJ'), ('modern', 'JJ'), ('smart', 'JJ'), ('TV', 'NN'), Tree('PERSON', [('Samsung', 'NNP')]), ('builds', 'VBZ'), ('TV', 'NN'), ("'s", 'POS'), ('to', 'TO'), ('last', 'JJ'), (',', ','), ('16', 'CD'), ('years', 'NNS'), ('is', 'VBZ'), ('a', 'DT'), ('long', 'JJ'), ('time', 'NN'), ('for', 'IN'), ('a', 'DT'), ('TV', 'NN'), ('hold', 'NN'), ('up', 'RP'), ('and', 'CC'), ('keep', 'VB'), ('working', 'VBG'), ('Anyway', 'RB'), ('A', 'NNP'), ('few', 'JJ'), ('weeks', 'NNS'), ('ago', 'RB'), ('I', 'PRP'), ('purchased', 'VBD'), ('a', 'DT'), ('43', 'CD'), ('inch', 'NN'), Tree('PERSON', [('Tu7000', 'NNP')]), ('for', 'IN'), ('the', 'DT'), ('bedroom', 'NN'), ('.', '.'), ('I', 'PRP'), ('was', 'VBD'), ('seeking', 'VBG'), ('a', 'DT'), ('thin', 'JJ'), ('modern', 'JJ'), ('affordable', 'JJ'), ('TV', 'NN'), ('with', 'IN'), ('a', 'DT'), ('great', 'JJ'), ('picture', 'NN'), ('This', 'DT'), ('was', 'VBD'), ('the', 'DT'), ('ultimate', 'JJ'), ('choice', 'NN'), ('!', '.'), ('I', 'PRP'), ('also', 'RB'), ('find', 'VBP'), ('this', 'DT'), ('model', 'NN'), ('has', 'VBZ'), ('decent', 'VBN'), ('internal', 'JJ'), ('sound', 'NN'), (',', ','), ('without', 'IN'), ('a', 'DT'), ('soundbar', 'NN'), ('but', 'CC'), ('of', 'IN'), ('course', 'NN'), ('you', 'PRP'), ('can', 'MD'), ('always', 'RB'), ('add', 'VB'), ('one', 'CD'), ('which', 'WDT'), ('I', 'PRP'), ("'ll", 'MD'), ('do', 'VB'), ('soon', 'RB'), ('to', 'TO'), ('watch', 'VB'), ('my', 'PRP$'), ('music', 'NN'), ('videos', 'NN'), ('.', '.'), ('.KateTheGreat00Written', 'VBN'), ('by', 'IN'), Tree('ORGANIZATION', [('aSamsung', 'NN')]), Tree('ORGANIZATION', [('UScustomer', 'NN')])])

# %%
# nltk.download('vader_lexicon')

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

sia = SentimentIntensityAnalyzer()

# %%
# sia

# %%
# sia.polarity_scores('this thing is very good')
# Out:
# {'neg': 0.0, 'neu': 0.556, 'pos': 0.444, 'compound': 0.4927}

# %%
# sia.polarity_scores('you are worst')
# Out:
# {'neg': 0.672, 'neu': 0.328, 'pos': 0.0, 'compound': -0.6249}

# %%
# sia.polarity_scores(example)
# Out:
# {'neg': 0.0, 'neu': 0.872, 'pos': 0.128, 'compound': 0.9392}

# %%
res={}
for i,row in tqdm(df3.iterrows(),total=len(df3)):
    text=row['reviews']
    myid=row['Unnamed: 0']
    res[myid]=sia.polarity_scores(text)
# Out:
#   0%|          | 0/286 [00:00<?, ?it/s]

# %%
vaders=pd.DataFrame(res).T
# vaders
# Out:
#        neg    neu    pos  compound
# 0    0.036  0.776  0.188    0.9364
# 1    0.042  0.766  0.191    0.8373
# 2    0.000  0.850  0.150    0.8906
# 3    0.000  0.740  0.260    0.9308
# 4    0.000  0.933  0.067    0.5423
# ..     ...    ...    ...       ...
# 281  0.000  0.796  0.204    0.9468
# 282  0.000  0.872  0.128    0.9392
# 283  0.075  0.787  0.138    0.8672
# 284  0.034  0.949  0.017   -0.4019
# 285  0.030  0.676  0.294    0.9842
#
# [286 rows x 4 columns]

# %%
#vaders=vaders.rename(columns={'index':'Unnamed: 0'})
Vaders = pd.merge(df3, vaders, left_index=True, right_index=True)
#vaders= vaders.merge(df3,left_on=None)

#vaders

# %%
# Vaders.head()
# Out:
#    Unnamed: 0                                            reviews Rating  \
# 0           0  Great features, able to play Xbox without cons...      4
# 1           1  Black dot on screenJust purchase this tv and a...      1
# 2           2  TV is so simple to use. This Samsung Crystal U...      5
# 3           3  Incredible Ease of navigation For someone bein...      5
# 4           4  it connects so seamlessly with my samsung earb...      5
#
#      neg    neu    pos  compound
# 0  0.036  0.776  0.188    0.9364
# 1  0.042  0.766  0.191    0.8373
# 2  0.000  0.850  0.150    0.8906
# 3  0.000  0.740  0.260    0.9308
# 4  0.000  0.933  0.067    0.5423

# %%
Vaders=Vaders.rename(columns={'Unnamed: 0':'index'})
#vaders=vaders.drop(columns=['level_0'])
# Vaders
# Out:
#      index                                            reviews Rating    neg  \
# 0        0  Great features, able to play Xbox without cons...      4  0.036
# 1        1  Black dot on screenJust purchase this tv and a...      1  0.042
# 2        2  TV is so simple to use. This Samsung Crystal U...      5  0.000
# 3        3  Incredible Ease of navigation For someone bein...      5  0.000
# 4        4  it connects so seamlessly with my samsung earb...      5  0.000
# ..     ...                                                ...    ...    ...
# 281    281  It has been a great tv since day one My family...      5  0.000
# 282    282  great quality at a great price I have an older...      5  0.000
# 283    283  Happy with the clear display I purchased my 43...      5  0.075
# 284    284  Solid tv for avg person So I have the 7000 ser...      4  0.034
# 285    285  Great, but blurry at night. Like I said, it is...      5  0.030
#
#        neu    pos  compound
# 0    0.776  0.188    0.9364
# 1    0.766  0.191    0.8373
# 2    0.850  0.150    0.8906
# 3    0.740  0.260    0.9308
# 4    0.933  0.067    0.5423
# ..     ...    ...       ...
# 281  0.796  0.204    0.9468
# 282  0.872  0.128    0.9392
# 283  0.787  0.138    0.8672
# 284  0.949  0.017   -0.4019
# 285  0.676  0.294    0.9842
#
# [286 rows x 7 columns]

# %%
Vaders['Rating']=Vaders['Rating'].astype(int)
# Vaders
# Out:
#      index                                            reviews  Rating    neg  \
# 0        0  Great features, able to play Xbox without cons...       4  0.036
# 1        1  Black dot on screenJust purchase this tv and a...       1  0.042
# 2        2  TV is so simple to use. This Samsung Crystal U...       5  0.000
# 3        3  Incredible Ease of navigation For someone bein...       5  0.000
# 4        4  it connects so seamlessly with my samsung earb...       5  0.000
# ..     ...                                                ...     ...    ...
# 281    281  It has been a great tv since day one My family...       5  0.000
# 282    282  great quality at a great price I have an older...       5  0.000
# 283    283  Happy with the clear display I purchased my 43...       5  0.075
# 284    284  Solid tv for avg person So I have the 7000 ser...       4  0.034
# 285    285  Great, but blurry at night. Like I said, it is...       5  0.030
#
#        neu    pos  compound
# 0    0.776  0.188    0.9364
# 1    0.766  0.191    0.8373
# 2    0.850  0.150    0.8906
# 3    0.740  0.260    0.9308
# 4    0.933  0.067    0.5423
# ..     ...    ...       ...
# 281  0.796  0.204    0.9468
# 282  0.872  0.128    0.9392
# 283  0.787  0.138    0.8672
# 284  0.949  0.017   -0.4019
# 285  0.676  0.294    0.9842
#
# [286 rows x 7 columns]

# %%
ax=sns.barplot(data=Vaders,x='Rating', y='compound')
ax.set_title('Compund rating by walmartStar reviews')
plt.show()

# %%
fig,axs=plt.subplots(1,3,figsize=(15,3))
sns.barplot(data=Vaders, x='Rating',y='pos',ax=axs[0])
sns.barplot(data=Vaders, x='Rating',y='neu',ax=axs[1])
sns.barplot(data=Vaders, x='Rating',y='neg',ax=axs[2])
axs[0].set_title('positive')
axs[1].set_title('neutral')
axs[2].set_title('negative')
plt.show()

# %%
# pip install transformers
#!pip install tensorflow

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %%
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer=AutoTokenizer.from_pretrained(MODEL)
model= AutoModelForSequenceClassification.from_pretrained(MODEL)

# %%
print(example)
sia.polarity_scores(example)
# Out:
# great quality at a great price I have an older 36" Samsung  (2006 Touch Of Red model)  I wanted to replace.    Not because it didn't work but because I wanted a new modern smart TV Samsung builds TV's to last,  16 years is a long time for a TV hold up and keep working
#     Anyway A few weeks ago I purchased  a 43 inch Tu7000 for the bedroom.    I was seeking a thin modern affordable TV with a great picture    This was the ultimate choice!   I also find this model has decent internal sound,  without a soundbar   but of course you can always add one which I'll do soon to watch my music videos.
# .KateTheGreat00Written by aSamsung UScustomer
# {'neg': 0.0, 'neu': 0.872, 'pos': 0.128, 'compound': 0.9392}

# %%
encoded_text=tokenizer(example, return_tensors='pt')
output=model(**encoded_text)
scores = output[0][0].detach().numpy()
scores = softmax(scores)
scores_dict={
    'roberta_neg': scores[0],
    'roberta_neu': scores[1],
    'roberta_pos': scores[2]
}
print(scores_dict)
# Out:
# {'roberta_neg': 0.008853892, 'roberta_neu': 0.07393544, 'roberta_pos': 0.9172107}

# %%
def polarity_scores_roberta(example):
    encoded_text=tokenizer(example, return_tensors='pt')
    output=model(**encoded_text)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    scores_dict={
    'roberta_neg': scores[0],
    'roberta_neu': scores[1],
    'roberta_pos': scores[2]
    }
    return scores_dict

# %%
res={}
for i,row in tqdm(df3.iterrows(),total=len(df3)):
    text=row['reviews']
    myid=row['Unnamed: 0']
    vader_result=sia.polarity_scores(text)
    vader_result_rename={}
    for key, value in vader_result.items():
        vader_result_rename[f"vader_{key}"]=value
    roberta_result=polarity_scores_roberta(text)
    both={**vader_result,**roberta_result}
    res[myid]=both
# Out:
#   0%|          | 0/286 [00:00<?, ?it/s]

# %%
res
# Out:
# {0: {'neg': 0.036,
#   'neu': 0.776,
#   'pos': 0.188,
#   'compound': 0.9364,
#   'roberta_neg': 0.005295404,
#   'roberta_neu': 0.027127108,
#   'roberta_pos': 0.9675775},
#  1: {'neg': 0.042,
#   'neu': 0.766,
#   'pos': 0.191,
#   'compound': 0.8373,
#   'roberta_neg': 0.6193724,
#   'roberta_neu': 0.29382458,
#   'roberta_pos': 0.08680298},
#  2: {'neg': 0.0,
#   'neu': 0.85,
#   'pos': 0.15,
#   'compound': 0.8906,
#   'roberta_neg': 0.0021306654,
#   'roberta_neu': 0.018964138,
#   'roberta_pos': 0.97890526},
#  3: {'neg': 0.0,
#   'neu': 0.74,
#   'pos': 0.26,
#   'compound': 0.9308,
#   'roberta_neg': 0.006318839,
#   'roberta_neu': 0.06472216,
#   'roberta_pos': 0.92895895},
#  4: {'neg': 0.0,
#   'neu': 0.933,
#   'pos': 0.067,
#   'compound': 0.5423,
#   'roberta_neg': 0.0022617462,
#   'roberta_neu': 0.025899945,
#   'roberta_pos': 0.9718383},
#  5: {'neg': 0.0,
#   'neu': 0.616,
#   'pos': 0.384,
#   'compound': 0.9713,
#   'roberta_neg': 0.0014268358,
#   'roberta_neu': 0.008038427,
#   'roberta_pos': 0.9905347},
#  6: {'neg': 0.0,
#   'neu': 0.726,
#   'pos': 0.274,
#   'compound': 0.9488,
#   'roberta_neg': 0.0024324998,
#   'roberta_neu': 0.02761931,
#   'roberta_pos': 0.96994823},
#  7: {'neg': 0.0,
#   'neu': 0.79,
#   'pos': 0.21,
#   'compound': 0.9224,
#   'roberta_neg': 0.0055271992,
#   'roberta_neu': 0.043962844,
#   'roberta_pos': 0.95050997},
#  8: {'neg': 0.0,
#   'neu': 0.801,
#   'pos': 0.199,
#   'compound': 0.8481,
#   'roberta_neg': 0.012979121,
#   'roberta_neu': 0.1349748,
#   'roberta_pos': 0.852046},
#  9: {'neg': 0.0,
#   'neu': 0.813,
#   'pos': 0.187,
#   'compound': 0.8553,
#   'roberta_neg': 0.00983863,
#   'roberta_neu': 0.10372185,
#   'roberta_pos': 0.88643956},
#  10: {'neg': 0.036,
#   'neu': 0.776,
#   'pos': 0.188,
#   'compound': 0.9364,
#   'roberta_neg': 0.0053159995,
#   'roberta_neu': 0.027664324,
#   'roberta_pos': 0.96701974},
#  11: {'neg': 0.105,
#   'neu': 0.818,
#   'pos': 0.077,
#   'compound': -0.3619,
#   'roberta_neg': 0.26488572,
#   'roberta_neu': 0.40830198,
#   'roberta_pos': 0.32681227},
#  12: {'neg': 0.0,
#   'neu': 0.762,
#   'pos': 0.238,
#   'compound': 0.9707,
#   'roberta_neg': 0.009000838,
#   'roberta_neu': 0.051620025,
#   'roberta_pos': 0.93937916},
#  13: {'neg': 0.0,
#   'neu': 0.589,
#   'pos': 0.411,
#   'compound': 0.9786,
#   'roberta_neg': 0.0014342511,
#   'roberta_neu': 0.010947218,
#   'roberta_pos': 0.98761857},
#  14: {'neg': 0.0,
#   'neu': 0.82,
#   'pos': 0.18,
#   'compound': 0.872,
#   'roberta_neg': 0.014761616,
#   'roberta_neu': 0.081189334,
#   'roberta_pos': 0.90404904},
#  15: {'neg': 0.046,
#   'neu': 0.804,
#   'pos': 0.15,
#   'compound': 0.7717,
#   'roberta_neg': 0.010207543,
#   'roberta_neu': 0.08464734,
#   'roberta_pos': 0.9051451},
#  16: {'neg': 0.0,
#   'neu': 0.636,
#   'pos': 0.364,
#   'compound': 0.978,
#   'roberta_neg': 0.0011250674,
#   'roberta_neu': 0.008617643,
#   'roberta_pos': 0.99025726},
#  17: {'neg': 0.024,
#   'neu': 0.628,
#   'pos': 0.348,
#   'compound': 0.9806,
#   'roberta_neg': 0.0026168409,
#   'roberta_neu': 0.032007825,
#   'roberta_pos': 0.96537536},
#  18: {'neg': 0.035,
#   'neu': 0.739,
#   'pos': 0.225,
#   'compound': 0.9062,
#   'roberta_neg': 0.0019192547,
#   'roberta_neu': 0.015382515,
#   'roberta_pos': 0.98269826},
#  19: {'neg': 0.0,
#   'neu': 0.706,
#   'pos': 0.294,
#   'compound': 0.9578,
#   'roberta_neg': 0.0026650217,
#   'roberta_neu': 0.037860267,
#   'roberta_pos': 0.95947474},
#  20: {'neg': 0.0,
#   'neu': 0.658,
#   'pos': 0.342,
#   'compound': 0.9625,
#   'roberta_neg': 0.0028339357,
#   'roberta_neu': 0.026851194,
#   'roberta_pos': 0.97031486},
#  21: {'neg': 0.0,
#   'neu': 0.783,
#   'pos': 0.217,
#   'compound': 0.9332,
#   'roberta_neg': 0.0012453409,
#   'roberta_neu': 0.0066786543,
#   'roberta_pos': 0.99207604},
#  22: {'neg': 0.036,
#   'neu': 0.776,
#   'pos': 0.188,
#   'compound': 0.9364,
#   'roberta_neg': 0.005295404,
#   'roberta_neu': 0.027127108,
#   'roberta_pos': 0.9675775},
#  23: {'neg': 0.042,
#   'neu': 0.766,
#   'pos': 0.191,
#   'compound': 0.8373,
#   'roberta_neg': 0.6193724,
#   'roberta_neu': 0.29382458,
#   'roberta_pos': 0.08680298},
#  24: {'neg': 0.0,
#   'neu': 0.658,
#   'pos': 0.342,
#   'compound': 0.9625,
#   'roberta_neg': 0.0028339357,
#   'roberta_neu': 0.026851194,
#   'roberta_pos': 0.97031486},
#  25: {'neg': 0.0,
#   'neu': 0.783,
#   'pos': 0.217,
#   'compound': 0.9332,
#   'roberta_neg': 0.0012453409,
#   'roberta_neu': 0.0066786543,
#   'roberta_pos': 0.99207604},
#  26: {'neg': 0.056,
#   'neu': 0.733,
#   'pos': 0.211,
#   'compound': 0.8779,
#   'roberta_neg': 0.0014980279,
#   'roberta_neu': 0.018462535,
#   'roberta_pos': 0.9800394},
#  27: {'neg': 0.042,
#   'neu': 0.735,
#   'pos': 0.224,
#   'compound': 0.9684,
#   'roberta_neg': 0.0051092803,
#   'roberta_neu': 0.04518073,
#   'roberta_pos': 0.94971},
#  28: {'neg': 0.058,
#   'neu': 0.669,
#   'pos': 0.273,
#   'compound': 0.9516,
#   'roberta_neg': 0.0018915659,
#   'roberta_neu': 0.0116005195,
#   'roberta_pos': 0.9865079},
#  29: {'neg': 0.019,
#   'neu': 0.623,
#   'pos': 0.358,
#   'compound': 0.9776,
#   'roberta_neg': 0.0025529873,
#   'roberta_neu': 0.010225569,
#   'roberta_pos': 0.9872214},
#  30: {'neg': 0.047,
#   'neu': 0.854,
#   'pos': 0.099,
#   'compound': 0.4753,
#   'roberta_neg': 0.007334398,
#   'roberta_neu': 0.101334214,
#   'roberta_pos': 0.8913313},
#  31: {'neg': 0.0,
#   'neu': 0.59,
#   'pos': 0.41,
#   'compound': 0.9914,
#   'roberta_neg': 0.0030059204,
#   'roberta_neu': 0.047407724,
#   'roberta_pos': 0.9495864},
#  32: {'neg': 0.0,
#   'neu': 0.713,
#   'pos': 0.287,
#   'compound': 0.9646,
#   'roberta_neg': 0.002628067,
#   'roberta_neu': 0.0071909255,
#   'roberta_pos': 0.9901811},
#  33: {'neg': 0.0,
#   'neu': 0.808,
#   'pos': 0.192,
#   'compound': 0.8735,
#   'roberta_neg': 0.0013241593,
#   'roberta_neu': 0.019532902,
#   'roberta_pos': 0.9791429},
#  34: {'neg': 0.049,
#   'neu': 0.706,
#   'pos': 0.245,
#   'compound': 0.9582,
#   'roberta_neg': 0.15754217,
#   'roberta_neu': 0.3003993,
#   'roberta_pos': 0.5420585},
#  35: {'neg': 0.0,
#   'neu': 0.687,
#   'pos': 0.313,
#   'compound': 0.9716,
#   'roberta_neg': 0.0015413684,
#   'roberta_neu': 0.01174094,
#   'roberta_pos': 0.9867177},
#  36: {'neg': 0.018,
#   'neu': 0.729,
#   'pos': 0.254,
#   'compound': 0.9834,
#   'roberta_neg': 0.0013940202,
#   'roberta_neu': 0.024714995,
#   'roberta_pos': 0.97389096},
#  37: {'neg': 0.0,
#   'neu': 0.74,
#   'pos': 0.26,
#   'compound': 0.9843,
#   'roberta_neg': 0.0059145275,
#   'roberta_neu': 0.02737492,
#   'roberta_pos': 0.96671057},
#  38: {'neg': 0.0,
#   'neu': 0.704,
#   'pos': 0.296,
#   'compound': 0.9633,
#   'roberta_neg': 0.0013122248,
#   'roberta_neu': 0.006261701,
#   'roberta_pos': 0.99242604},
#  39: {'neg': 0.029,
#   'neu': 0.893,
#   'pos': 0.078,
#   'compound': 0.5314,
#   'roberta_neg': 0.006293473,
#   'roberta_neu': 0.06344148,
#   'roberta_pos': 0.930265},
#  40: {'neg': 0.0,
#   'neu': 0.792,
#   'pos': 0.208,
#   'compound': 0.9245,
#   'roberta_neg': 0.0014309123,
#   'roberta_neu': 0.011856074,
#   'roberta_pos': 0.98671305},
#  41: {'neg': 0.033,
#   'neu': 0.718,
#   'pos': 0.249,
#   'compound': 0.9322,
#   'roberta_neg': 0.0033917539,
#   'roberta_neu': 0.024249122,
#   'roberta_pos': 0.9723591},
#  42: {'neg': 0.0,
#   'neu': 0.598,
#   'pos': 0.402,
#   'compound': 0.9691,
#   'roberta_neg': 0.0023193196,
#   'roberta_neu': 0.011540635,
#   'roberta_pos': 0.98614},
#  43: {'neg': 0.138,
#   'neu': 0.712,
#   'pos': 0.15,
#   'compound': 0.3422,
#   'roberta_neg': 0.5211825,
#   'roberta_neu': 0.30169004,
#   'roberta_pos': 0.17712747},
#  44: {'neg': 0.036,
#   'neu': 0.776,
#   'pos': 0.188,
#   'compound': 0.9364,
#   'roberta_neg': 0.005295404,
#   'roberta_neu': 0.027127108,
#   'roberta_pos': 0.9675775},
#  45: {'neg': 0.013,
#   'neu': 0.855,
#   'pos': 0.132,
#   'compound': 0.8688,
#   'roberta_neg': 0.5044562,
#   'roberta_neu': 0.3766293,
#   'roberta_pos': 0.11891451},
#  46: {'neg': 0.033,
#   'neu': 0.755,
#   'pos': 0.212,
#   'compound': 0.938,
#   'roberta_neg': 0.0032862097,
#   'roberta_neu': 0.012833055,
#   'roberta_pos': 0.9838807},
#  47: {'neg': 0.0,
#   'neu': 0.801,
#   'pos': 0.199,
#   'compound': 0.8481,
#   'roberta_neg': 0.014142544,
#   'roberta_neu': 0.14019974,
#   'roberta_pos': 0.8456577},
#  48: {'neg': 0.042,
#   'neu': 0.766,
#   'pos': 0.191,
#   'compound': 0.8373,
#   'roberta_neg': 0.6246235,
#   'roberta_neu': 0.28633565,
#   'roberta_pos': 0.08904086},
#  49: {'neg': 0.0,
#   'neu': 0.801,
#   'pos': 0.199,
#   'compound': 0.8271,
#   'roberta_neg': 0.001753511,
#   'roberta_neu': 0.019518066,
#   'roberta_pos': 0.9787284},
#  50: {'neg': 0.0,
#   'neu': 0.493,
#   'pos': 0.507,
#   'compound': 0.9846,
#   'roberta_neg': 0.0013412379,
#   'roberta_neu': 0.013327093,
#   'roberta_pos': 0.98533165},
#  51: {'neg': 0.025,
#   'neu': 0.748,
#   'pos': 0.227,
#   'compound': 0.8928,
#   'roberta_neg': 0.1625246,
#   'roberta_neu': 0.23774417,
#   'roberta_pos': 0.59973127},
#  52: {'neg': 0.0,
#   'neu': 0.631,
#   'pos': 0.369,
#   'compound': 0.9773,
#   'roberta_neg': 0.00257727,
#   'roberta_neu': 0.023551565,
#   'roberta_pos': 0.9738712},
#  53: {'neg': 0.0,
#   'neu': 0.693,
#   'pos': 0.307,
#   'compound': 0.986,
#   'roberta_neg': 0.0019654229,
#   'roberta_neu': 0.006590549,
#   'roberta_pos': 0.99144405},
#  54: {'neg': 0.0,
#   'neu': 0.611,
#   'pos': 0.389,
#   'compound': 0.9748,
#   'roberta_neg': 0.0013616082,
#   'roberta_neu': 0.006788118,
#   'roberta_pos': 0.9918502},
#  55: {'neg': 0.0,
#   'neu': 0.633,
#   'pos': 0.367,
#   'compound': 0.9817,
#   'roberta_neg': 0.0012840739,
#   'roberta_neu': 0.0124661755,
#   'roberta_pos': 0.9862497},
#  56: {'neg': 0.0,
#   'neu': 0.74,
#   'pos': 0.26,
#   'compound': 0.9308,
#   'roberta_neg': 0.006499752,
#   'roberta_neu': 0.066095054,
#   'roberta_pos': 0.9274052},
#  57: {'neg': 0.018,
#   'neu': 0.664,
#   'pos': 0.318,
#   'compound': 0.9885,
#   'roberta_neg': 0.0014841221,
#   'roberta_neu': 0.00902325,
#   'roberta_pos': 0.98949265},
#  58: {'neg': 0.079,
#   'neu': 0.704,
#   'pos': 0.218,
#   'compound': 0.8591,
#   'roberta_neg': 0.0018198503,
#   'roberta_neu': 0.023006568,
#   'roberta_pos': 0.9751736},
#  59: {'neg': 0.024,
#   'neu': 0.779,
#   'pos': 0.197,
#   'compound': 0.8795,
#   'roberta_neg': 0.030995015,
#   'roberta_neu': 0.13274664,
#   'roberta_pos': 0.83625835},
#  60: {'neg': 0.016,
#   'neu': 0.684,
#   'pos': 0.299,
#   'compound': 0.9902,
#   'roberta_neg': 0.0014068829,
#   'roberta_neu': 0.009001313,
#   'roberta_pos': 0.9895918},
#  61: {'neg': 0.031,
#   'neu': 0.798,
#   'pos': 0.171,
#   'compound': 0.9565,
#   'roberta_neg': 0.0445543,
#   'roberta_neu': 0.18081033,
#   'roberta_pos': 0.7746354},
#  62: {'neg': 0.061,
#   'neu': 0.693,
#   'pos': 0.246,
#   'compound': 0.9391,
#   'roberta_neg': 0.0016142098,
#   'roberta_neu': 0.01327835,
#   'roberta_pos': 0.9851075},
#  63: {'neg': 0.038,
#   'neu': 0.618,
#   'pos': 0.344,
#   'compound': 0.9601,
#   'roberta_neg': 0.021539282,
#   'roberta_neu': 0.094410814,
#   'roberta_pos': 0.8840499},
#  64: {'neg': 0.038,
#   'neu': 0.752,
#   'pos': 0.21,
#   'compound': 0.985,
#   'roberta_neg': 0.0015539497,
#   'roberta_neu': 0.01767348,
#   'roberta_pos': 0.9807726},
#  65: {'neg': 0.0,
#   'neu': 0.779,
#   'pos': 0.221,
#   'compound': 0.964,
#   'roberta_neg': 0.0021370957,
#   'roberta_neu': 0.024228834,
#   'roberta_pos': 0.97363406},
#  66: {'neg': 0.0,
#   'neu': 0.645,
#   'pos': 0.355,
#   'compound': 0.943,
#   'roberta_neg': 0.0014214372,
#   'roberta_neu': 0.013891602,
#   'roberta_pos': 0.9846869},
#  67: {'neg': 0.123,
#   'neu': 0.731,
#   'pos': 0.146,
#   'compound': 0.2023,
#   'roberta_neg': 0.63356185,
#   'roberta_neu': 0.32357755,
#   'roberta_pos': 0.04286062},
#  68: {'neg': 0.102,
#   'neu': 0.743,
#   'pos': 0.155,
#   'compound': 0.8098,
#   'roberta_neg': 0.4556315,
#   'roberta_neu': 0.3662147,
#   'roberta_pos': 0.17815384},
#  69: {'neg': 0.0,
#   'neu': 0.673,
#   'pos': 0.327,
#   'compound': 0.9771,
#   'roberta_neg': 0.002306138,
#   'roberta_neu': 0.0056872503,
#   'roberta_pos': 0.9920066},
#  70: {'neg': 0.0,
#   'neu': 0.506,
#   'pos': 0.494,
#   'compound': 0.9927,
#   'roberta_neg': 0.0020302306,
#   'roberta_neu': 0.009726592,
#   'roberta_pos': 0.98824316},
#  71: {'neg': 0.014,
#   'neu': 0.733,
#   'pos': 0.253,
#   'compound': 0.9677,
#   'roberta_neg': 0.0063101077,
#   'roberta_neu': 0.03468486,
#   'roberta_pos': 0.95900506},
#  72: {'neg': 0.0,
#   'neu': 0.852,
#   'pos': 0.148,
#   'compound': 0.765,
#   'roberta_neg': 0.004822417,
#   'roberta_neu': 0.04793879,
#   'roberta_pos': 0.94723874},
#  73: {'neg': 0.0,
#   'neu': 0.762,
#   'pos': 0.238,
#   'compound': 0.9514,
#   'roberta_neg': 0.0018051238,
#   'roberta_neu': 0.0060838163,
#   'roberta_pos': 0.9921111},
#  74: {'neg': 0.084,
#   'neu': 0.825,
#   'pos': 0.091,
#   'compound': 0.3421,
#   'roberta_neg': 0.48613682,
#   'roberta_neu': 0.40393633,
#   'roberta_pos': 0.10992683},
#  75: {'neg': 0.092,
#   'neu': 0.815,
#   'pos': 0.093,
#   'compound': 0.4682,
#   'roberta_neg': 0.04069915,
#   'roberta_neu': 0.115863666,
#   'roberta_pos': 0.8434372},
#  76: {'neg': 0.0,
#   'neu': 0.657,
#   'pos': 0.343,
#   'compound': 0.9766,
#   'roberta_neg': 0.0014497794,
#   'roberta_neu': 0.01124932,
#   'roberta_pos': 0.9873009},
#  77: {'neg': 0.0,
#   'neu': 0.773,
#   'pos': 0.227,
#   'compound': 0.9509,
#   'roberta_neg': 0.0028611254,
#   'roberta_neu': 0.011912622,
#   'roberta_pos': 0.9852262},
#  78: {'neg': 0.0,
#   'neu': 0.685,
#   'pos': 0.315,
#   'compound': 0.984,
#   'roberta_neg': 0.0021760312,
#   'roberta_neu': 0.007722311,
#   'roberta_pos': 0.9901017},
#  79: {'neg': 0.0,
#   'neu': 0.806,
#   'pos': 0.194,
#   'compound': 0.8779,
#   'roberta_neg': 0.0018937232,
#   'roberta_neu': 0.016543886,
#   'roberta_pos': 0.9815624},
#  80: {'neg': 0.0,
#   'neu': 0.807,
#   'pos': 0.193,
#   'compound': 0.9628,
#   'roberta_neg': 0.0018178988,
#   'roberta_neu': 0.009932005,
#   'roberta_pos': 0.98825014},
#  81: {'neg': 0.0,
#   'neu': 0.75,
#   'pos': 0.25,
#   'compound': 0.9325,
#   'roberta_neg': 0.0027880403,
#   'roberta_neu': 0.033516843,
#   'roberta_pos': 0.96369517},
#  82: {'neg': 0.0,
#   'neu': 0.734,
#   'pos': 0.266,
#   'compound': 0.9888,
#   'roberta_neg': 0.0041872915,
#   'roberta_neu': 0.019088479,
#   'roberta_pos': 0.97672427},
#  83: {'neg': 0.034,
#   'neu': 0.791,
#   'pos': 0.175,
#   'compound': 0.9329,
#   'roberta_neg': 0.0338144,
#   'roberta_neu': 0.1151181,
#   'roberta_pos': 0.8510675},
#  84: {'neg': 0.087,
#   'neu': 0.746,
#   'pos': 0.168,
#   'compound': 0.3506,
#   'roberta_neg': 0.018380005,
#   'roberta_neu': 0.060684714,
#   'roberta_pos': 0.9209353},
#  85: {'neg': 0.0,
#   'neu': 0.637,
#   'pos': 0.363,
#   'compound': 0.9708,
#   'roberta_neg': 0.0015339918,
#   'roberta_neu': 0.01268407,
#   'roberta_pos': 0.9857819},
#  86: {'neg': 0.0,
#   'neu': 0.634,
#   'pos': 0.366,
#   'compound': 0.997,
#   'roberta_neg': 0.004243757,
#   'roberta_neu': 0.0405146,
#   'roberta_pos': 0.9552416},
#  87: {'neg': 0.03,
#   'neu': 0.725,
#   'pos': 0.245,
#   'compound': 0.9596,
#   'roberta_neg': 0.0018499604,
#   'roberta_neu': 0.012395057,
#   'roberta_pos': 0.98575497},
#  88: {'neg': 0.119,
#   'neu': 0.708,
#   'pos': 0.173,
#   'compound': 0.8573,
#   'roberta_neg': 0.0124981245,
#   'roberta_neu': 0.05994688,
#   'roberta_pos': 0.927555},
#  89: {'neg': 0.013,
#   'neu': 0.737,
#   'pos': 0.249,
#   'compound': 0.9773,
#   'roberta_neg': 0.14659828,
#   'roberta_neu': 0.3595685,
#   'roberta_pos': 0.49383318},
#  90: {'neg': 0.123,
#   'neu': 0.837,
#   'pos': 0.04,
#   'compound': -0.5692,
#   'roberta_neg': 0.95078677,
#   'roberta_neu': 0.044648692,
#   'roberta_pos': 0.004564544},
#  91: {'neg': 0.038,
#   'neu': 0.807,
#   'pos': 0.154,
#   'compound': 0.8481,
#   'roberta_neg': 0.21372755,
#   'roberta_neu': 0.45172435,
#   'roberta_pos': 0.33454806},
#  92: {'neg': 0.051,
#   'neu': 0.835,
#   'pos': 0.113,
#   'compound': 0.6961,
#   'roberta_neg': 0.23041238,
#   'roberta_neu': 0.41466817,
#   'roberta_pos': 0.3549195},
#  93: {'neg': 0.048,
#   'neu': 0.952,
#   'pos': 0.0,
#   'compound': -0.4019,
#   'roberta_neg': 0.066817604,
#   'roberta_neu': 0.36129442,
#   'roberta_pos': 0.57188797},
#  94: {'neg': 0.0,
#   'neu': 0.588,
#   'pos': 0.412,
#   'compound': 0.4215,
#   'roberta_neg': 0.0013041472,
#   'roberta_neu': 0.041467026,
#   'roberta_pos': 0.95722884},
#  95: {'neg': 0.097,
#   'neu': 0.866,
#   'pos': 0.037,
#   'compound': -0.4949,
#   'roberta_neg': 0.94567114,
#   'roberta_neu': 0.05025047,
#   'roberta_pos': 0.0040784203},
#  96: {'neg': 0.0,
#   'neu': 0.897,
#   'pos': 0.103,
#   'compound': 0.7264,
#   'roberta_neg': 0.503022,
#   'roberta_neu': 0.45139492,
#   'roberta_pos': 0.04558311},
#  97: {'neg': 0.0,
#   'neu': 0.809,
#   'pos': 0.191,
#   'compound': 0.8176,
#   'roberta_neg': 0.0035925985,
#   'roberta_neu': 0.04029381,
#   'roberta_pos': 0.9561136},
#  98: {'neg': 0.195,
#   'neu': 0.805,
#   'pos': 0.0,
#   'compound': -0.8034,
#   'roberta_neg': 0.956569,
#   'roberta_neu': 0.038674496,
#   'roberta_pos': 0.0047565443},
#  99: {'neg': 0.0,
#   'neu': 0.785,
#   'pos': 0.215,
#   'compound': 0.8682,
#   'roberta_neg': 0.0021510993,
#   'roberta_neu': 0.008847074,
#   'roberta_pos': 0.98900187},
#  100: {'neg': 0.037,
#   'neu': 0.699,
#   'pos': 0.263,
#   'compound': 0.9684,
#   'roberta_neg': 0.07671667,
#   'roberta_neu': 0.13646908,
#   'roberta_pos': 0.7868143},
#  101: {'neg': 0.176,
#   'neu': 0.762,
#   'pos': 0.062,
#   'compound': -0.9136,
#   'roberta_neg': 0.8216188,
#   'roberta_neu': 0.15679719,
#   'roberta_pos': 0.021584023},
#  102: {'neg': 0.025,
#   'neu': 0.679,
#   'pos': 0.296,
#   'compound': 0.9652,
#   'roberta_neg': 0.003884027,
#   'roberta_neu': 0.01612848,
#   'roberta_pos': 0.9799875},
#  103: {'neg': 0.068,
#   'neu': 0.583,
#   'pos': 0.349,
#   'compound': 0.9693,
#   'roberta_neg': 0.0019292742,
#   'roberta_neu': 0.010015747,
#   'roberta_pos': 0.98805505},
#  104: {'neg': 0.12,
#   'neu': 0.755,
#   'pos': 0.125,
#   'compound': 0.1324,
#   'roberta_neg': 0.51569784,
#   'roberta_neu': 0.3646717,
#   'roberta_pos': 0.119630486},
#  105: {'neg': 0.0,
#   'neu': 0.648,
#   'pos': 0.352,
#   'compound': 0.9821,
#   'roberta_neg': 0.0023066234,
#   'roberta_neu': 0.016087921,
#   'roberta_pos': 0.98160547},
#  106: {'neg': 0.0,
#   'neu': 0.848,
#   'pos': 0.152,
#   'compound': 0.8858,
#   'roberta_neg': 0.0030188197,
#   'roberta_neu': 0.027822252,
#   'roberta_pos': 0.9691589},
#  107: {'neg': 0.122,
#   'neu': 0.796,
#   'pos': 0.082,
#   'compound': -0.3182,
#   'roberta_neg': 0.6669801,
#   'roberta_neu': 0.27280554,
#   'roberta_pos': 0.06021433},
#  108: {'neg': 0.03,
#   'neu': 0.715,
#   'pos': 0.255,
#   'compound': 0.988,
#   'roberta_neg': 0.0027717222,
#   'roberta_neu': 0.020526187,
#   'roberta_pos': 0.9767021},
#  109: {'neg': 0.023,
#   'neu': 0.578,
#   'pos': 0.399,
#   'compound': 0.9886,
#   'roberta_neg': 0.0016472859,
#   'roberta_neu': 0.0060687885,
#   'roberta_pos': 0.992284},
#  110: {'neg': 0.02,
#   'neu': 0.894,
#   'pos': 0.086,
#   'compound': 0.8279,
#   'roberta_neg': 0.01573487,
#   'roberta_neu': 0.07724015,
#   'roberta_pos': 0.907025},
#  111: {'neg': 0.084,
#   'neu': 0.825,
#   'pos': 0.091,
#   'compound': 0.3421,
#   'roberta_neg': 0.4815159,
#   'roberta_neu': 0.4055922,
#   'roberta_pos': 0.11289189},
#  112: {'neg': 0.119,
#   'neu': 0.842,
#   'pos': 0.039,
#   'compound': -0.7505,
#   'roberta_neg': 0.041002028,
#   'roberta_neu': 0.10657075,
#   'roberta_pos': 0.8524272},
#  113: {'neg': 0.046,
#   'neu': 0.78,
#   'pos': 0.174,
#   'compound': 0.9197,
#   'roberta_neg': 0.0019410151,
#   'roberta_neu': 0.014483783,
#   'roberta_pos': 0.9835752},
#  114: {'neg': 0.022,
#   'neu': 0.754,
#   'pos': 0.224,
#   'compound': 0.9754,
#   'roberta_neg': 0.0033394485,
#   'roberta_neu': 0.009503899,
#   'roberta_pos': 0.98715657},
#  115: {'neg': 0.0,
#   'neu': 0.647,
#   'pos': 0.353,
#   'compound': 0.9843,
#   'roberta_neg': 0.0021469384,
#   'roberta_neu': 0.007989954,
#   'roberta_pos': 0.98986316},
#  116: {'neg': 0.0,
#   'neu': 0.627,
#   'pos': 0.373,
#   'compound': 0.9693,
#   'roberta_neg': 0.0015209586,
#   'roberta_neu': 0.006358746,
#   'roberta_pos': 0.99212027},
#  117: {'neg': 0.0,
#   'neu': 0.703,
#   'pos': 0.297,
#   'compound': 0.9709,
#   'roberta_neg': 0.0016365846,
#   'roberta_neu': 0.007843812,
#   'roberta_pos': 0.99051964},
#  118: {'neg': 0.057,
#   'neu': 0.666,
#   'pos': 0.277,
#   'compound': 0.9626,
#   'roberta_neg': 0.0017014694,
#   'roberta_neu': 0.009489183,
#   'roberta_pos': 0.9888094},
#  119: {'neg': 0.061,
#   'neu': 0.737,
#   'pos': 0.203,
#   'compound': 0.7855,
#   'roberta_neg': 0.0016483858,
#   'roberta_neu': 0.009007725,
#   'roberta_pos': 0.9893439},
#  120: {'neg': 0.02,
#   'neu': 0.732,
#   'pos': 0.248,
#   'compound': 0.9897,
#   'roberta_neg': 0.028474705,
#   'roberta_neu': 0.125562,
#   'roberta_pos': 0.84596336},
#  121: {'neg': 0.218,
#   'neu': 0.591,
#   'pos': 0.191,
#   'compound': 0.124,
#   'roberta_neg': 0.014455036,
#   'roberta_neu': 0.044304717,
#   'roberta_pos': 0.94124025},
#  122: {'neg': 0.0,
#   'neu': 0.706,
#   'pos': 0.294,
#   'compound': 0.9771,
#   'roberta_neg': 0.0013592055,
#   'roberta_neu': 0.0112014,
#   'roberta_pos': 0.98743945},
#  123: {'neg': 0.0,
#   'neu': 0.663,
#   'pos': 0.337,
#   'compound': 0.9629,
#   'roberta_neg': 0.0013687426,
#   'roberta_neu': 0.011897919,
#   'roberta_pos': 0.9867334},
#  124: {'neg': 0.0,
#   'neu': 0.688,
#   'pos': 0.312,
#   'compound': 0.9678,
#   'roberta_neg': 0.0017777977,
#   'roberta_neu': 0.009347887,
#   'roberta_pos': 0.9888743},
#  125: {'neg': 0.0,
#   'neu': 0.586,
#   'pos': 0.414,
#   'compound': 0.9761,
#   'roberta_neg': 0.0014260764,
#   'roberta_neu': 0.008898566,
#   'roberta_pos': 0.98967534},
#  126: {'neg': 0.0,
#   'neu': 0.7,
#   'pos': 0.3,
#   'compound': 0.9839,
#   'roberta_neg': 0.0027029687,
#   'roberta_neu': 0.019421292,
#   'roberta_pos': 0.9778757},
#  127: {'neg': 0.033,
#   'neu': 0.751,
#   'pos': 0.216,
#   'compound': 0.985,
#   'roberta_neg': 0.15339507,
#   'roberta_neu': 0.28876838,
#   'roberta_pos': 0.5578366},
#  128: {'neg': 0.0,
#   'neu': 0.731,
#   'pos': 0.269,
#   'compound': 0.9861,
#   'roberta_neg': 0.001434726,
#   'roberta_neu': 0.061875705,
#   'roberta_pos': 0.9366896},
#  129: {'neg': 0.0,
#   'neu': 0.611,
#   'pos': 0.389,
#   'compound': 0.9937,
#   'roberta_neg': 0.0018309295,
#   'roberta_neu': 0.010744262,
#   'roberta_pos': 0.9874248},
#  130: {'neg': 0.0,
#   'neu': 0.696,
#   'pos': 0.304,
#   'compound': 0.9917,
#   'roberta_neg': 0.0013805688,
#   'roberta_neu': 0.006439472,
#   'roberta_pos': 0.99218},
#  131: {'neg': 0.0,
#   'neu': 0.787,
#   'pos': 0.213,
#   'compound': 0.7574,
#   'roberta_neg': 0.1455151,
#   'roberta_neu': 0.28431284,
#   'roberta_pos': 0.5701721},
#  132: {'neg': 0.036,
#   'neu': 0.776,
#   'pos': 0.188,
#   'compound': 0.9364,
#   'roberta_neg': 0.005295404,
#   'roberta_neu': 0.027127108,
#   'roberta_pos': 0.9675775},
#  133: {'neg': 0.013,
#   'neu': 0.855,
#   'pos': 0.132,
#   'compound': 0.8688,
#   'roberta_neg': 0.5044562,
#   'roberta_neu': 0.3766293,
#   'roberta_pos': 0.11891451},
#  134: {'neg': 0.058,
#   'neu': 0.898,
#   'pos': 0.043,
#   'compound': -0.0258,
#   'roberta_neg': 0.85232794,
#   'roberta_neu': 0.13256304,
#   'roberta_pos': 0.015109054},
#  135: {'neg': 0.0,
#   'neu': 0.81,
#   'pos': 0.19,
#   'compound': 0.958,
#   'roberta_neg': 0.0037810935,
#   'roberta_neu': 0.018178469,
#   'roberta_pos': 0.97804046},
#  136: {'neg': 0.0,
#   'neu': 0.631,
#   'pos': 0.369,
#   'compound': 0.9692,
#   'roberta_neg': 0.0018348312,
#   'roberta_neu': 0.005937838,
#   'roberta_pos': 0.9922273},
#  137: {'neg': 0.0,
#   'neu': 0.593,
#   'pos': 0.407,
#   'compound': 0.9287,
#   'roberta_neg': 0.00260877,
#   'roberta_neu': 0.014009577,
#   'roberta_pos': 0.9833816},
#  138: {'neg': 0.041,
#   'neu': 0.721,
#   'pos': 0.239,
#   'compound': 0.9217,
#   'roberta_neg': 0.0041643726,
#   'roberta_neu': 0.02552586,
#   'roberta_pos': 0.97030973},
#  139: {'neg': 0.0,
#   'neu': 0.737,
#   'pos': 0.263,
#   'compound': 0.9393,
#   'roberta_neg': 0.0016401026,
#   'roberta_neu': 0.015467824,
#   'roberta_pos': 0.98289204},
#  140: {'neg': 0.0,
#   'neu': 0.788,
#   'pos': 0.212,
#   'compound': 0.9575,
#   'roberta_neg': 0.0063557527,
#   'roberta_neu': 0.036286086,
#   'roberta_pos': 0.9573582},
#  141: {'neg': 0.0,
#   'neu': 0.725,
#   'pos': 0.275,
#   'compound': 0.9598,
#   'roberta_neg': 0.002862931,
#   'roberta_neu': 0.01808936,
#   'roberta_pos': 0.9790477},
#  142: {'neg': 0.0,
#   'neu': 0.533,
#   'pos': 0.467,
#   'compound': 0.9937,
#   'roberta_neg': 0.0033451123,
#   'roberta_neu': 0.011765962,
#   'roberta_pos': 0.9848889},
#  143: {'neg': 0.0,
#   'neu': 0.558,
#   'pos': 0.442,
#   'compound': 0.9812,
#   'roberta_neg': 0.001613571,
#   'roberta_neu': 0.012859457,
#   'roberta_pos': 0.9855269},
#  144: {'neg': 0.0,
#   'neu': 0.627,
#   'pos': 0.373,
#   'compound': 0.984,
#   'roberta_neg': 0.0019746814,
#   'roberta_neu': 0.00605376,
#   'roberta_pos': 0.9919715},
#  145: {'neg': 0.031,
#   'neu': 0.737,
#   'pos': 0.232,
#   'compound': 0.8973,
#   'roberta_neg': 0.035949618,
#   'roberta_neu': 0.12693186,
#   'roberta_pos': 0.8371185},
#  146: {'neg': 0.0,
#   'neu': 0.822,
#   'pos': 0.178,
#   'compound': 0.9667,
#   'roberta_neg': 0.0034315302,
#   'roberta_neu': 0.016495949,
#   'roberta_pos': 0.9800725},
#  147: {'neg': 0.0,
#   'neu': 0.875,
#   'pos': 0.125,
#   'compound': 0.7896,
#   'roberta_neg': 0.0025525063,
#   'roberta_neu': 0.01678296,
#   'roberta_pos': 0.9806645},
#  148: {'neg': 0.0,
#   'neu': 0.738,
#   'pos': 0.262,
#   'compound': 0.9313,
#   'roberta_neg': 0.0013014587,
#   'roberta_neu': 0.020976853,
#   'roberta_pos': 0.97772175},
#  149: {'neg': 0.0,
#   'neu': 0.833,
#   'pos': 0.167,
#   'compound': 0.8122,
#   'roberta_neg': 0.018077115,
#   'roberta_neu': 0.061910693,
#   'roberta_pos': 0.92001224},
#  150: {'neg': 0.025,
#   'neu': 0.888,
#   'pos': 0.087,
#   'compound': 0.6003,
#   'roberta_neg': 0.52802867,
#   'roberta_neu': 0.36854863,
#   'roberta_pos': 0.1034227},
#  151: {'neg': 0.08,
#   'neu': 0.77,
#   'pos': 0.15,
#   'compound': 0.5713,
#   'roberta_neg': 0.399825,
#   'roberta_neu': 0.4159886,
#   'roberta_pos': 0.18418638},
#  152: {'neg': 0.046,
#   'neu': 0.954,
#   'pos': 0.0,
#   'compound': -0.3612,
#   'roberta_neg': 0.9332855,
#   'roberta_neu': 0.058982056,
#   'roberta_pos': 0.0077323765},
#  153: {'neg': 0.056,
#   'neu': 0.758,
#   'pos': 0.186,
#   'compound': 0.9463,
#   'roberta_neg': 0.0045613423,
#   'roberta_neu': 0.017859655,
#   'roberta_pos': 0.97757894},
#  154: {'neg': 0.0,
#   'neu': 0.66,
#   'pos': 0.34,
#   'compound': 0.9438,
#   'roberta_neg': 0.0031149709,
#   'roberta_neu': 0.015962582,
#   'roberta_pos': 0.9809224},
#  155: {'neg': 0.202,
#   'neu': 0.761,
#   'pos': 0.037,
#   'compound': -0.8479,
#   'roberta_neg': 0.9194805,
#   'roberta_neu': 0.07457107,
#   'roberta_pos': 0.0059485016},
#  156: {'neg': 0.0,
#   'neu': 0.663,
#   'pos': 0.337,
#   'compound': 0.9834,
#   'roberta_neg': 0.0017262449,
#   'roberta_neu': 0.007227549,
#   'roberta_pos': 0.99104625},
#  157: {'neg': 0.02,
#   'neu': 0.615,
#   'pos': 0.365,
#   'compound': 0.9735,
#   'roberta_neg': 0.0021342065,
#   'roberta_neu': 0.0059442203,
#   'roberta_pos': 0.99192154},
#  158: {'neg': 0.0,
#   'neu': 0.513,
#   'pos': 0.487,
#   'compound': 0.9853,
#   'roberta_neg': 0.0016695368,
#   'roberta_neu': 0.006306144,
#   'roberta_pos': 0.9920243},
#  159: {'neg': 0.053,
#   'neu': 0.657,
#   'pos': 0.291,
#   'compound': 0.9218,
#   'roberta_neg': 0.003003475,
#   'roberta_neu': 0.0137653,
#   'roberta_pos': 0.9832312},
#  160: {'neg': 0.0,
#   'neu': 0.7,
#   'pos': 0.3,
#   'compound': 0.9857,
#   'roberta_neg': 0.0015862646,
#   'roberta_neu': 0.010528974,
#   'roberta_pos': 0.9878848},
#  161: {'neg': 0.0,
#   'neu': 0.69,
#   'pos': 0.31,
#   'compound': 0.9866,
#   'roberta_neg': 0.0015883661,
#   'roberta_neu': 0.009454873,
#   'roberta_pos': 0.98895675},
#  162: {'neg': 0.0,
#   'neu': 0.586,
#   'pos': 0.414,
#   'compound': 0.981,
#   'roberta_neg': 0.0016342999,
#   'roberta_neu': 0.0067675756,
#   'roberta_pos': 0.9915981},
#  163: {'neg': 0.044,
#   'neu': 0.736,
#   'pos': 0.221,
#   'compound': 0.872,
#   'roberta_neg': 0.012412189,
#   'roberta_neu': 0.077305086,
#   'roberta_pos': 0.9102828},
#  164: {'neg': 0.025,
#   'neu': 0.919,
#   'pos': 0.056,
#   'compound': 0.34,
#   'roberta_neg': 0.16283666,
#   'roberta_neu': 0.4050054,
#   'roberta_pos': 0.43215796},
#  165: {'neg': 0.1,
#   'neu': 0.533,
#   'pos': 0.367,
#   'compound': 0.9684,
#   'roberta_neg': 0.0020613628,
#   'roberta_neu': 0.005721423,
#   'roberta_pos': 0.9922172},
#  166: {'neg': 0.0,
#   'neu': 0.718,
#   'pos': 0.282,
#   'compound': 0.9698,
#   'roberta_neg': 0.0014753593,
#   'roberta_neu': 0.015927197,
#   'roberta_pos': 0.9825974},
#  167: {'neg': 0.049,
#   'neu': 0.653,
#   'pos': 0.298,
#   'compound': 0.9544,
#   'roberta_neg': 0.001972812,
#   'roberta_neu': 0.0052937698,
#   'roberta_pos': 0.99273336},
#  168: {'neg': 0.0,
#   'neu': 0.746,
#   'pos': 0.254,
#   'compound': 0.9643,
#   'roberta_neg': 0.0017031375,
#   'roberta_neu': 0.010090266,
#   'roberta_pos': 0.98820657},
#  169: {'neg': 0.038,
#   'neu': 0.771,
#   'pos': 0.192,
#   'compound': 0.9593,
#   'roberta_neg': 0.040159706,
#   'roberta_neu': 0.09317323,
#   'roberta_pos': 0.8666671},
#  170: {'neg': 0.083,
#   'neu': 0.677,
#   'pos': 0.239,
#   'compound': 0.8976,
#   'roberta_neg': 0.0010628907,
#   'roberta_neu': 0.0072407643,
#   'roberta_pos': 0.99169636},
#  171: {'neg': 0.018,
#   'neu': 0.654,
#   'pos': 0.329,
#   'compound': 0.9865,
#   'roberta_neg': 0.0028021287,
#   'roberta_neu': 0.01897222,
#   'roberta_pos': 0.97822565},
#  172: {'neg': 0.0,
#   'neu': 0.795,
#   'pos': 0.205,
#   'compound': 0.9805,
#   'roberta_neg': 0.0016881224,
#   'roberta_neu': 0.023300868,
#   'roberta_pos': 0.97501105},
#  173: {'neg': 0.0,
#   'neu': 0.772,
#   'pos': 0.228,
#   'compound': 0.9183,
#   'roberta_neg': 0.0015532979,
#   'roberta_neu': 0.010923445,
#   'roberta_pos': 0.98752326},
#  174: {'neg': 0.0,
#   'neu': 0.777,
#   'pos': 0.223,
#   'compound': 0.9552,
#   'roberta_neg': 0.004606447,
#   'roberta_neu': 0.04288505,
#   'roberta_pos': 0.9525085},
#  175: {'neg': 0.0,
#   'neu': 0.589,
#   'pos': 0.411,
#   'compound': 0.9821,
#   'roberta_neg': 0.0015736563,
#   'roberta_neu': 0.006983671,
#   'roberta_pos': 0.9914426},
#  176: {'neg': 0.065,
#   'neu': 0.691,
#   'pos': 0.244,
#   'compound': 0.9283,
#   'roberta_neg': 0.022835823,
#   'roberta_neu': 0.07053338,
#   'roberta_pos': 0.9066308},
#  177: {'neg': 0.062,
#   'neu': 0.816,
#   'pos': 0.122,
#   'compound': 0.8826,
#   'roberta_neg': 0.3402918,
#   'roberta_neu': 0.28919065,
#   'roberta_pos': 0.37051752},
#  178: {'neg': 0.0,
#   'neu': 0.767,
#   'pos': 0.233,
#   'compound': 0.7067,
#   'roberta_neg': 0.0035127087,
#   'roberta_neu': 0.05149388,
#   'roberta_pos': 0.9449934},
#  179: {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'roberta_neg': 0.008079793,
#   'roberta_neu': 0.5195115,
#   'roberta_pos': 0.47240865},
#  180: {'neg': 0.0,
#   'neu': 0.735,
#   'pos': 0.265,
#   'compound': 0.7579,
#   'roberta_neg': 0.001805245,
#   'roberta_neu': 0.029065443,
#   'roberta_pos': 0.9691293},
#  181: {'neg': 0.082,
#   'neu': 0.703,
#   'pos': 0.215,
#   'compound': 0.5267,
#   'roberta_neg': 0.6977086,
#   'roberta_neu': 0.2796436,
#   'roberta_pos': 0.022647781},
#  182: {'neg': 0.0,
#   'neu': 0.837,
#   'pos': 0.163,
#   'compound': 0.6249,
#   'roberta_neg': 0.002335389,
#   'roberta_neu': 0.010631766,
#   'roberta_pos': 0.9870329},
#  183: {'neg': 0.093,
#   'neu': 0.569,
#   'pos': 0.337,
#   'compound': 0.7906,
#   'roberta_neg': 0.0045617423,
#   'roberta_neu': 0.03063509,
#   'roberta_pos': 0.9648032},
#  184: {'neg': 0.0,
#   'neu': 0.771,
#   'pos': 0.229,
#   'compound': 0.7384,
#   'roberta_neg': 0.0031776603,
#   'roberta_neu': 0.027272275,
#   'roberta_pos': 0.96955},
#  185: {'neg': 0.0,
#   'neu': 0.773,
#   'pos': 0.227,
#   'compound': 0.6249,
#   'roberta_neg': 0.0029291173,
#   'roberta_neu': 0.023567528,
#   'roberta_pos': 0.9735033},
#  186: {'neg': 0.0,
#   'neu': 0.561,
#   'pos': 0.439,
#   'compound': 0.9231,
#   'roberta_neg': 0.0013808012,
#   'roberta_neu': 0.017994223,
#   'roberta_pos': 0.9806249},
#  187: {'neg': 0.0,
#   'neu': 0.594,
#   'pos': 0.406,
#   'compound': 0.9118,
#   'roberta_neg': 0.0022468304,
#   'roberta_neu': 0.010054309,
#   'roberta_pos': 0.9876988},
#  188: {'neg': 0.0,
#   'neu': 0.652,
#   'pos': 0.348,
#   'compound': 0.9042,
#   'roberta_neg': 0.0013203945,
#   'roberta_neu': 0.009225746,
#   'roberta_pos': 0.9894539},
#  189: {'neg': 0.0,
#   'neu': 0.792,
#   'pos': 0.208,
#   'compound': 0.6369,
#   'roberta_neg': 0.0065871775,
#   'roberta_neu': 0.03817874,
#   'roberta_pos': 0.9552341},
#  190: {'neg': 0.0,
#   'neu': 0.731,
#   'pos': 0.269,
#   'compound': 0.7096,
#   'roberta_neg': 0.0026152409,
#   'roberta_neu': 0.056976963,
#   'roberta_pos': 0.9404078},
#  191: {'neg': 0.0,
#   'neu': 0.781,
#   'pos': 0.219,
#   'compound': 0.6369,
#   'roberta_neg': 0.003310554,
#   'roberta_neu': 0.025327317,
#   'roberta_pos': 0.9713622},
#  192: {'neg': 0.0,
#   'neu': 0.645,
#   'pos': 0.355,
#   'compound': 0.8999,
#   'roberta_neg': 0.0012216754,
#   'roberta_neu': 0.0072264383,
#   'roberta_pos': 0.9915519},
#  193: {'neg': 0.0,
#   'neu': 0.729,
#   'pos': 0.271,
#   'compound': 0.7717,
#   'roberta_neg': 0.0063741403,
#   'roberta_neu': 0.04721338,
#   'roberta_pos': 0.94641244},
#  194: {'neg': 0.0,
#   'neu': 0.83,
#   'pos': 0.17,
#   'compound': 0.6249,
#   'roberta_neg': 0.0015838416,
#   'roberta_neu': 0.032310635,
#   'roberta_pos': 0.9661055},
#  195: {'neg': 0.0,
#   'neu': 0.654,
#   'pos': 0.346,
#   'compound': 0.8402,
#   'roberta_neg': 0.0027623114,
#   'roberta_neu': 0.039848022,
#   'roberta_pos': 0.95738965},
#  196: {'neg': 0.0,
#   'neu': 0.88,
#   'pos': 0.12,
#   'compound': 0.3802,
#   'roberta_neg': 0.00742125,
#   'roberta_neu': 0.13360532,
#   'roberta_pos': 0.8589734},
#  197: {'neg': 0.0,
#   'neu': 0.753,
#   'pos': 0.247,
#   'compound': 0.7096,
#   'roberta_neg': 0.002575457,
#   'roberta_neu': 0.037434887,
#   'roberta_pos': 0.9599897},
#  198: {'neg': 0.0,
#   'neu': 0.66,
#   'pos': 0.34,
#   'compound': 0.9438,
#   'roberta_neg': 0.0031149709,
#   'roberta_neu': 0.015962582,
#   'roberta_pos': 0.9809224},
#  199: {'neg': 0.202,
#   'neu': 0.761,
#   'pos': 0.037,
#   'compound': -0.8479,
#   'roberta_neg': 0.9194805,
#   'roberta_neu': 0.07457107,
#   'roberta_pos': 0.0059485016},
#  200: {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'roberta_neg': 0.035503298,
#   'roberta_neu': 0.92537403,
#   'roberta_pos': 0.039122704},
#  201: {'neg': 0.083,
#   'neu': 0.832,
#   'pos': 0.085,
#   'compound': 0.3542,
#   'roberta_neg': 0.8814796,
#   'roberta_neu': 0.10653644,
#   'roberta_pos': 0.011983949},
#  202: {'neg': 0.224,
#   'neu': 0.776,
#   'pos': 0.0,
#   'compound': -0.7579,
#   'roberta_neg': 0.7072319,
#   'roberta_neu': 0.25816917,
#   'roberta_pos': 0.034598958},
#  203: {'neg': 0.251,
#   'neu': 0.599,
#   'pos': 0.15,
#   'compound': -0.5719,
#   'roberta_neg': 0.71818095,
#   'roberta_neu': 0.24268328,
#   'roberta_pos': 0.03913581},
#  204: {'neg': 0.0,
#   'neu': 0.9,
#   'pos': 0.1,
#   'compound': 0.5859,
#   'roberta_neg': 0.38751116,
#   'roberta_neu': 0.4955619,
#   'roberta_pos': 0.11692697},
#  205: {'neg': 0.149,
#   'neu': 0.72,
#   'pos': 0.132,
#   'compound': -0.1779,
#   'roberta_neg': 0.48102954,
#   'roberta_neu': 0.40576118,
#   'roberta_pos': 0.1132092},
#  206: {'neg': 0.0,
#   'neu': 0.866,
#   'pos': 0.134,
#   'compound': 0.6597,
#   'roberta_neg': 0.6844462,
#   'roberta_neu': 0.23691611,
#   'roberta_pos': 0.07863762},
#  207: {'neg': 0.0,
#   'neu': 0.533,
#   'pos': 0.467,
#   'compound': 0.9802,
#   'roberta_neg': 0.0018031825,
#   'roberta_neu': 0.01016201,
#   'roberta_pos': 0.9880348},
#  208: {'neg': 0.0,
#   'neu': 0.615,
#   'pos': 0.385,
#   'compound': 0.946,
#   'roberta_neg': 0.0042539686,
#   'roberta_neu': 0.04131929,
#   'roberta_pos': 0.9544267},
#  209: {'neg': 0.136,
#   'neu': 0.745,
#   'pos': 0.118,
#   'compound': -0.0767,
#   'roberta_neg': 0.8077947,
#   'roberta_neu': 0.1741802,
#   'roberta_pos': 0.018025065},
#  210: {'neg': 0.09,
#   'neu': 0.48,
#   'pos': 0.43,
#   'compound': 0.9388,
#   'roberta_neg': 0.0016491538,
#   'roberta_neu': 0.007980394,
#   'roberta_pos': 0.99037045},
#  211: {'neg': 0.0,
#   'neu': 0.672,
#   'pos': 0.328,
#   'compound': 0.9701,
#   'roberta_neg': 0.0017719555,
#   'roberta_neu': 0.014126891,
#   'roberta_pos': 0.9841011},
#  212: {'neg': 0.075,
#   'neu': 0.712,
#   'pos': 0.213,
#   'compound': 0.9022,
#   'roberta_neg': 0.011659128,
#   'roberta_neu': 0.0392212,
#   'roberta_pos': 0.9491196},
#  213: {'neg': 0.072,
#   'neu': 0.871,
#   'pos': 0.056,
#   'compound': -0.3182,
#   'roberta_neg': 0.71297896,
#   'roberta_neu': 0.23277809,
#   'roberta_pos': 0.054243032},
#  214: {'neg': 0.0,
#   'neu': 0.785,
#   'pos': 0.215,
#   'compound': 0.6588,
#   'roberta_neg': 0.0033487442,
#   'roberta_neu': 0.034034662,
#   'roberta_pos': 0.9626166},
#  215: {'neg': 0.0,
#   'neu': 0.642,
#   'pos': 0.358,
#   'compound': 0.9459,
#   'roberta_neg': 0.001399626,
#   'roberta_neu': 0.012768722,
#   'roberta_pos': 0.9858316},
#  216: {'neg': 0.114,
#   'neu': 0.78,
#   'pos': 0.106,
#   'compound': -0.1027,
#   'roberta_neg': 0.016431365,
#   'roberta_neu': 0.14522724,
#   'roberta_pos': 0.83834136},
#  217: {'neg': 0.07,
#   'neu': 0.777,
#   'pos': 0.153,
#   'compound': 0.4717,
#   'roberta_neg': 0.00890936,
#   'roberta_neu': 0.05823291,
#   'roberta_pos': 0.9328577},
#  218: {'neg': 0.041,
#   'neu': 0.691,
#   'pos': 0.268,
#   'compound': 0.8353,
#   'roberta_neg': 0.004281272,
#   'roberta_neu': 0.018758003,
#   'roberta_pos': 0.9769607},
#  219: {'neg': 0.089,
#   'neu': 0.692,
#   'pos': 0.219,
#   'compound': 0.539,
#   'roberta_neg': 0.4109225,
#   'roberta_neu': 0.4337893,
#   'roberta_pos': 0.15528817},
#  220: {'neg': 0.048,
#   'neu': 0.907,
#   'pos': 0.045,
#   'compound': -0.3071,
#   'roberta_neg': 0.021177936,
#   'roberta_neu': 0.1900471,
#   'roberta_pos': 0.788775},
#  221: {'neg': 0.053,
#   'neu': 0.873,
#   'pos': 0.074,
#   'compound': 0.5215,
#   'roberta_neg': 0.85813075,
#   'roberta_neu': 0.121818356,
#   'roberta_pos': 0.02005099},
#  222: {'neg': 0.065,
#   'neu': 0.834,
#   'pos': 0.101,
#   'compound': 0.746,
#   'roberta_neg': 0.34100786,
#   'roberta_neu': 0.36418924,
#   'roberta_pos': 0.2948029},
#  223: {'neg': 0.0,
#   'neu': 0.723,
#   'pos': 0.277,
#   'compound': 0.9552,
#   'roberta_neg': 0.0021036658,
#   'roberta_neu': 0.0108445315,
#   'roberta_pos': 0.98705184},
#  224: {'neg': 0.0,
#   'neu': 0.714,
#   'pos': 0.286,
#   'compound': 0.9721,
#   'roberta_neg': 0.0016911862,
#   'roberta_neu': 0.014561323,
#   'roberta_pos': 0.98374754},
#  225: {'neg': 0.0,
#   'neu': 0.796,
#   'pos': 0.204,
#   'compound': 0.9468,
#   'roberta_neg': 0.0014456988,
#   'roberta_neu': 0.009274773,
#   'roberta_pos': 0.98927957},
#  226: {'neg': 0.0,
#   'neu': 0.872,
#   'pos': 0.128,
#   'compound': 0.9392,
#   'roberta_neg': 0.008853892,
#   'roberta_neu': 0.07393544,
#   'roberta_pos': 0.9172107},
#  227: {'neg': 0.075,
#   'neu': 0.787,
#   'pos': 0.138,
#   'compound': 0.8672,
#   'roberta_neg': 0.11852304,
#   'roberta_neu': 0.32672817,
#   'roberta_pos': 0.5547488},
#  228: {'neg': 0.034,
#   'neu': 0.949,
#   'pos': 0.017,
#   'compound': -0.4019,
#   'roberta_neg': 0.4053578,
#   'roberta_neu': 0.44887593,
#   'roberta_pos': 0.1457662},
#  229: {'neg': 0.03,
#   'neu': 0.676,
#   'pos': 0.294,
#   'compound': 0.9842,
#   'roberta_neg': 0.008003063,
#   'roberta_neu': 0.049552187,
#   'roberta_pos': 0.9424447},
#  230: {'neg': 0.016,
#   'neu': 0.795,
#   'pos': 0.19,
#   'compound': 0.9758,
#   'roberta_neg': 0.0014862784,
#   'roberta_neu': 0.009146231,
#   'roberta_pos': 0.98936754},
#  231: {'neg': 0.0,
#   'neu': 0.891,
#   'pos': 0.109,
#   'compound': 0.81,
#   'roberta_neg': 0.001950672,
#   'roberta_neu': 0.028279204,
#   'roberta_pos': 0.9697702},
#  232: {'neg': 0.035,
#   'neu': 0.846,
#   'pos': 0.119,
#   'compound': 0.881,
#   'roberta_neg': 0.024355454,
#   'roberta_neu': 0.14314243,
#   'roberta_pos': 0.83250207},
#  233: {'neg': 0.0,
#   'neu': 0.659,
#   'pos': 0.341,
#   'compound': 0.9745,
#   'roberta_neg': 0.0023347253,
#   'roberta_neu': 0.017720178,
#   'roberta_pos': 0.97994506},
#  234: {'neg': 0.06,
#   'neu': 0.711,
#   'pos': 0.23,
#   'compound': 0.9808,
#   'roberta_neg': 0.0027149867,
#   'roberta_neu': 0.01738,
#   'roberta_pos': 0.979905},
#  235: {'neg': 0.0,
#   'neu': 0.735,
#   'pos': 0.265,
#   'compound': 0.9916,
#   'roberta_neg': 0.001854872,
#   'roberta_neu': 0.007458222,
#   'roberta_pos': 0.99068695},
#  236: {'neg': 0.0,
#   'neu': 0.751,
#   'pos': 0.249,
#   'compound': 0.9512,
#   'roberta_neg': 0.001214829,
#   'roberta_neu': 0.006608464,
#   'roberta_pos': 0.9921767},
#  237: {'neg': 0.0,
#   'neu': 0.696,
#   'pos': 0.304,
#   'compound': 0.991,
#   'roberta_neg': 0.0012324444,
#   'roberta_neu': 0.010109605,
#   'roberta_pos': 0.9886579},
#  238: {'neg': 0.072,
#   'neu': 0.689,
#   'pos': 0.239,
#   'compound': 0.9432,
#   'roberta_neg': 0.0073631434,
#   'roberta_neu': 0.030003157,
#   'roberta_pos': 0.9626337},
#  239: {'neg': 0.0,
#   'neu': 0.61,
#   'pos': 0.39,
#   'compound': 0.9709,
#   'roberta_neg': 0.0014150161,
#   'roberta_neu': 0.017799767,
#   'roberta_pos': 0.98078525},
#  240: {'neg': 0.0,
#   'neu': 0.685,
#   'pos': 0.315,
#   'compound': 0.9851,
#   'roberta_neg': 0.0018596278,
#   'roberta_neu': 0.009587684,
#   'roberta_pos': 0.9885527},
#  241: {'neg': 0.064,
#   'neu': 0.697,
#   'pos': 0.239,
#   'compound': 0.9381,
#   'roberta_neg': 0.0063240984,
#   'roberta_neu': 0.025995506,
#   'roberta_pos': 0.96768034},
#  242: {'neg': 0.02,
#   'neu': 0.894,
#   'pos': 0.086,
#   'compound': 0.8279,
#   'roberta_neg': 0.01573487,
#   'roberta_neu': 0.07724015,
#   'roberta_pos': 0.907025},
#  243: {'neg': 0.033,
#   'neu': 0.835,
#   'pos': 0.132,
#   'compound': 0.7751,
#   'roberta_neg': 0.9026759,
#   'roberta_neu': 0.08419186,
#   'roberta_pos': 0.013132203},
#  244: {'neg': 0.0,
#   'neu': 0.554,
#   'pos': 0.446,
#   'compound': 0.9022,
#   'roberta_neg': 0.0010181416,
#   'roberta_neu': 0.008520436,
#   'roberta_pos': 0.9904614},
#  245: {'neg': 0.0,
#   'neu': 0.601,
#   'pos': 0.399,
#   'compound': 0.6096,
#   'roberta_neg': 0.0021671953,
#   'roberta_neu': 0.06852696,
#   'roberta_pos': 0.92930585},
#  246: {'neg': 0.279,
#   'neu': 0.721,
#   'pos': 0.0,
#   'compound': -0.4767,
#   'roberta_neg': 0.91807353,
#   'roberta_neu': 0.07827967,
#   'roberta_pos': 0.0036467041},
#  247: {'neg': 0.0,
#   'neu': 0.523,
#   'pos': 0.477,
#   'compound': 0.807,
#   'roberta_neg': 0.001437284,
#   'roberta_neu': 0.024365997,
#   'roberta_pos': 0.9741967},
#  248: {'neg': 0.0,
#   'neu': 0.781,
#   'pos': 0.219,
#   'compound': 0.4215,
#   'roberta_neg': 0.0015154779,
#   'roberta_neu': 0.0906707,
#   'roberta_pos': 0.9078138},
#  249: {'neg': 0.0,
#   'neu': 0.792,
#   'pos': 0.208,
#   'compound': 0.6369,
#   'roberta_neg': 0.0014660169,
#   'roberta_neu': 0.009907748,
#   'roberta_pos': 0.9886262},
#  250: {'neg': 0.0,
#   'neu': 0.838,
#   'pos': 0.162,
#   'compound': 0.4019,
#   'roberta_neg': 0.0033682608,
#   'roberta_neu': 0.027283797,
#   'roberta_pos': 0.9693479},
#  251: {'neg': 0.0,
#   'neu': 0.775,
#   'pos': 0.225,
#   'compound': 0.5399,
#   'roberta_neg': 0.0014339872,
#   'roberta_neu': 0.01570658,
#   'roberta_pos': 0.98285943},
#  252: {'neg': 0.0,
#   'neu': 0.539,
#   'pos': 0.461,
#   'compound': 0.8555,
#   'roberta_neg': 0.0026747135,
#   'roberta_neu': 0.11884174,
#   'roberta_pos': 0.8784836},
#  253: {'neg': 0.123,
#   'neu': 0.729,
#   'pos': 0.149,
#   'compound': -0.0525,
#   'roberta_neg': 0.1198511,
#   'roberta_neu': 0.32432574,
#   'roberta_pos': 0.55582315},
#  254: {'neg': 0.0,
#   'neu': 0.765,
#   'pos': 0.235,
#   'compound': 0.5229,
#   'roberta_neg': 0.0016746955,
#   'roberta_neu': 0.015228976,
#   'roberta_pos': 0.98309636},
#  255: {'neg': 0.0,
#   'neu': 0.79,
#   'pos': 0.21,
#   'compound': 0.4927,
#   'roberta_neg': 0.0023742893,
#   'roberta_neu': 0.0722773,
#   'roberta_pos': 0.9253484},
#  256: {'neg': 0.0,
#   'neu': 0.702,
#   'pos': 0.298,
#   'compound': 0.643,
#   'roberta_neg': 0.0014806362,
#   'roberta_neu': 0.015114486,
#   'roberta_pos': 0.9834049},
#  257: {'neg': 0.0,
#   'neu': 0.656,
#   'pos': 0.344,
#   'compound': 0.8881,
#   'roberta_neg': 0.0011203557,
#   'roberta_neu': 0.008756699,
#   'roberta_pos': 0.990123},
#  258: {'neg': 0.0,
#   'neu': 0.614,
#   'pos': 0.386,
#   'compound': 0.8469,
#   'roberta_neg': 0.0016124437,
#   'roberta_neu': 0.006400736,
#   'roberta_pos': 0.9919869},
#  259: {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'roberta_neg': 0.007018725,
#   'roberta_neu': 0.28972846,
#   'roberta_pos': 0.7032528},
#  260: {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'roberta_neg': 0.002227318,
#   'roberta_neu': 0.05155099,
#   'roberta_pos': 0.94622165},
#  261: {'neg': 0.145,
#   'neu': 0.855,
#   'pos': 0.0,
#   'compound': -0.1759,
#   'roberta_neg': 0.003196951,
#   'roberta_neu': 0.017724926,
#   'roberta_pos': 0.9790781},
#  262: {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'roberta_neg': 0.003690532,
#   'roberta_neu': 0.048533097,
#   'roberta_pos': 0.9477763},
#  263: {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'roberta_neg': 0.0041424753,
#   'roberta_neu': 0.055313222,
#   'roberta_pos': 0.94054425},
#  264: {'neg': 0.0,
#   'neu': 0.57,
#   'pos': 0.43,
#   'compound': 0.9483,
#   'roberta_neg': 0.0011686593,
#   'roberta_neu': 0.009296014,
#   'roberta_pos': 0.9895354},
#  265: {'neg': 0.068,
#   'neu': 0.847,
#   'pos': 0.085,
#   'compound': 0.4417,
#   'roberta_neg': 0.96031356,
#   'roberta_neu': 0.035218254,
#   'roberta_pos': 0.004468209},
#  266: {'neg': 0.0,
#   'neu': 0.699,
#   'pos': 0.301,
#   'compound': 0.9606,
#   'roberta_neg': 0.0023565837,
#   'roberta_neu': 0.014325951,
#   'roberta_pos': 0.9833175},
#  267: {'neg': 0.018,
#   'neu': 0.711,
#   'pos': 0.271,
#   'compound': 0.9875,
#   'roberta_neg': 0.0022032121,
#   'roberta_neu': 0.008998791,
#   'roberta_pos': 0.98879796},
#  268: {'neg': 0.025,
#   'neu': 0.689,
#   'pos': 0.286,
#   'compound': 0.9741,
#   'roberta_neg': 0.0014292491,
#   'roberta_neu': 0.007213461,
#   'roberta_pos': 0.9913573},
#  269: {'neg': 0.076,
#   'neu': 0.652,
#   'pos': 0.272,
#   'compound': 0.928,
#   'roberta_neg': 0.0022507852,
#   'roberta_neu': 0.030008087,
#   'roberta_pos': 0.9677411},
#  270: {'neg': 0.074,
#   'neu': 0.773,
#   'pos': 0.153,
#   'compound': 0.7506,
#   'roberta_neg': 0.49633786,
#   'roberta_neu': 0.31898636,
#   'roberta_pos': 0.18467574},
#  271: {'neg': 0.011,
#   'neu': 0.892,
#   'pos': 0.097,
#   'compound': 0.923,
#   'roberta_neg': 0.03157438,
#   'roberta_neu': 0.28225765,
#   'roberta_pos': 0.68616796},
#  272: {'neg': 0.041,
#   'neu': 0.729,
#   'pos': 0.23,
#   'compound': 0.9022,
#   'roberta_neg': 0.0389029,
#   'roberta_neu': 0.13753368,
#   'roberta_pos': 0.82356346},
#  273: {'neg': 0.075,
#   'neu': 0.752,
#   'pos': 0.173,
#   'compound': 0.7906,
#   'roberta_neg': 0.006910946,
#   'roberta_neu': 0.06207603,
#   'roberta_pos': 0.93101305},
#  274: {'neg': 0.0,
#   'neu': 0.733,
#   'pos': 0.267,
#   'compound': 0.9335,
#   'roberta_neg': 0.001704924,
#   'roberta_neu': 0.0065279487,
#   'roberta_pos': 0.9917671},
#  275: {'neg': 0.051,
#   'neu': 0.703,
#   'pos': 0.246,
#   'compound': 0.9661,
#   'roberta_neg': 0.00261706,
#   'roberta_neu': 0.015155796,
#   'roberta_pos': 0.98222715},
#  276: {'neg': 0.038,
#   'neu': 0.734,
#   'pos': 0.228,
#   'compound': 0.9434,
#   'roberta_neg': 0.0025638265,
#   'roberta_neu': 0.015415396,
#   'roberta_pos': 0.9820208},
#  277: {'neg': 0.0,
#   'neu': 0.766,
#   'pos': 0.234,
#   'compound': 0.9717,
#   'roberta_neg': 0.0016522291,
#   'roberta_neu': 0.008267814,
#   'roberta_pos': 0.99008},
#  278: {'neg': 0.065,
#   'neu': 0.834,
#   'pos': 0.101,
#   'compound': 0.746,
#   'roberta_neg': 0.34100786,
#   'roberta_neu': 0.36418924,
#   'roberta_pos': 0.2948029},
#  279: {'neg': 0.0,
#   'neu': 0.723,
#   'pos': 0.277,
#   'compound': 0.9552,
#   'roberta_neg': 0.0021036658,
#   'roberta_neu': 0.0108445315,
#   'roberta_pos': 0.98705184},
#  280: {'neg': 0.0,
#   'neu': 0.714,
#   'pos': 0.286,
#   'compound': 0.9721,
#   'roberta_neg': 0.0016911862,
#   'roberta_neu': 0.014561323,
#   'roberta_pos': 0.98374754},
#  281: {'neg': 0.0,
#   'neu': 0.796,
#   'pos': 0.204,
#   'compound': 0.9468,
#   'roberta_neg': 0.0014456988,
#   'roberta_neu': 0.009274773,
#   'roberta_pos': 0.98927957},
#  282: {'neg': 0.0,
#   'neu': 0.872,
#   'pos': 0.128,
#   'compound': 0.9392,
#   'roberta_neg': 0.008853892,
#   'roberta_neu': 0.07393544,
#   'roberta_pos': 0.9172107},
#  283: {'neg': 0.075,
#   'neu': 0.787,
#   'pos': 0.138,
#   'compound': 0.8672,
#   'roberta_neg': 0.11852304,
#   'roberta_neu': 0.32672817,
#   'roberta_pos': 0.5547488},
#  284: {'neg': 0.034,
#   'neu': 0.949,
#   'pos': 0.017,
#   'compound': -0.4019,
#   'roberta_neg': 0.4053578,
#   'roberta_neu': 0.44887593,
#   'roberta_pos': 0.1457662},
#  285: {'neg': 0.03,
#   'neu': 0.676,
#   'pos': 0.294,
#   'compound': 0.9842,
#   'roberta_neg': 0.008003063,
#   'roberta_neu': 0.049552187,
#   'roberta_pos': 0.9424447}}

# %%
# Vaders.head()
# Out:
#    index                                            reviews  Rating    neg  \
# 0      0  Great features, able to play Xbox without cons...       4  0.036
# 1      1  Black dot on screenJust purchase this tv and a...       1  0.042
# 2      2  TV is so simple to use. This Samsung Crystal U...       5  0.000
# 3      3  Incredible Ease of navigation For someone bein...       5  0.000
# 4      4  it connects so seamlessly with my samsung earb...       5  0.000
#
#      neu    pos  compound
# 0  0.776  0.188    0.9364
# 1  0.766  0.191    0.8373
# 2  0.850  0.150    0.8906
# 3  0.740  0.260    0.9308
# 4  0.933  0.067    0.5423

# %%
df3=df3.rename(columns={'Unnamed: 0':'Id'})

# %%
# df3.head()
# Out:
#    Id                                            reviews Rating
# 0   0  Great features, able to play Xbox without cons...      4
# 1   1  Black dot on screenJust purchase this tv and a...      1
# 2   2  TV is so simple to use. This Samsung Crystal U...      5
# 3   3  Incredible Ease of navigation For someone bein...      5
# 4   4  it connects so seamlessly with my samsung earb...      5

# %%
# results_df.head()

# %%
df3['Rating'] = pd.to_numeric(df3['Rating'], errors='coerce')

# %%
results_df=pd.DataFrame(res).T
results_df=results_df.reset_index().rename(columns={'index':'Id'})
# results_df=results_df.merge(df3,how='left')
results_df = results_df.merge(df3, how='left', on='Id')

# %%
results_df.head()
# Out:
#    Id    neg    neu    pos  compound  roberta_neg  roberta_neu  roberta_pos  \
# 0   0  0.036  0.776  0.188    0.9364     0.005295     0.027127     0.967578
# 1   1  0.042  0.766  0.191    0.8373     0.619372     0.293825     0.086803
# 2   2  0.000  0.850  0.150    0.8906     0.002131     0.018964     0.978905
# 3   3  0.000  0.740  0.260    0.9308     0.006319     0.064722     0.928959
# 4   4  0.000  0.933  0.067    0.5423     0.002262     0.025900     0.971838
#
#                                              reviews  Rating
# 0  Great features, able to play Xbox without cons...       4
# 1  Black dot on screenJust purchase this tv and a...       1
# 2  TV is so simple to use. This Samsung Crystal U...       5
# 3  Incredible Ease of navigation For someone bein...       5
# 4  it connects so seamlessly with my samsung earb...       5

# %%
results_df.head()
# Out:
#    Id    neg    neu    pos  compound  roberta_neg  roberta_neu  roberta_pos  \
# 0   0  0.036  0.776  0.188    0.9364     0.005295     0.027127     0.967578
# 1   1  0.042  0.766  0.191    0.8373     0.619372     0.293825     0.086803
# 2   2  0.000  0.850  0.150    0.8906     0.002131     0.018964     0.978905
# 3   3  0.000  0.740  0.260    0.9308     0.006319     0.064722     0.928959
# 4   4  0.000  0.933  0.067    0.5423     0.002262     0.025900     0.971838
#
#                                              reviews  Rating
# 0  Great features, able to play Xbox without cons...       4
# 1  Black dot on screenJust purchase this tv and a...       1
# 2  TV is so simple to use. This Samsung Crystal U...       5
# 3  Incredible Ease of navigation For someone bein...       5
# 4  it connects so seamlessly with my samsung earb...       5

# %%
sns.pairplot(data=results_df,
             vars=['neg', 'neu', 'pos','roberta_neg', 'roberta_neu','roberta_pos'],
             hue='Rating',
             palette='tab10')
plt.show()
# Out:
# C:\Users\mammaruddin\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
from transformers import pipeline

# %%
sent_pipeline=pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
sent_pipeline(example)
# Out:
# [{'label': 'NEGATIVE', 'score': 0.7467999458312988}]

# %%
sent_pipeline('bad')
# Out:
# [{'label': 'NEGATIVE', 'score': 0.999782383441925}]
